# %% [markdown]
#  ### 3 (4) возможных способа найти упоминания товара в тексте
#  1. Обратиться к названиям товаров + описаниям для того, чтобы выделить паттерны для правил yargy. По этим правилам выделить товары в отзывах. Нюансы:
#  - очень много работы вручную, можно что-то проглядеть или составить слишком много правил
#  - можно увеличить полноту товаров
#  2. Можно обратиться к ключевым словам в отзывах, а затем их отфильтровать. Перед этим отфильтровать отзывы от стоп-слов (они не могут быть товарами), убрать пунктуацию. Нюансы:
#  - придется фильтровать полученые результаты (возможно с применением правил)/добавлять что-то
#  - полнота и точность могут быть низкими
#  3. Взять векторные представления текстов, взять названия товаров из metadata. Из названий типа "Seed Scrub" брать обобщающие названия товаров (scrub, shampoo etc) и искать векторную близость (tfidf, bm25) этих названий и текстов. Затем из полученных текстов выделить n-граммы. Нюансы:
#  - возможно, корреляция между настоящими названиями и названиями людей товаров будут слабыми (люди могут странно называть товары)
#  - сможем объединить все синонимичные упоминания (apple watch, watch)
#  4. Обучить на корпусе отзывов word2vec, взять из metadata обобщающие названия (те же shampoo, scrub) и найти наиболее близкие слова. Составить n-граммы (в которых могут быть сложные названия). Нюансы:
#  - легко получим синонимичные слова, встречающиеся в похожих контекстах
#  - возможны лишние слова

# %%
import pandas as pd
import gzip
import json
from tqdm.auto import tqdm
import nltk
nltk.download('averaged_perceptron_tagger')
import re
from collections import Counter
import gensim
from nltk.collocations import *
import spacy
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
tokenizer = RegexpTokenizer(r'\w+')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/assmirnova/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/assmirnova/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
df = getDF('Beauty_5.json.gz')

# %%
reviews = df['reviewText']
reviews
# Out:
# 0         Very oily and creamy. Not at all what I expect...
# 1         This palette was a decent price and I was look...
# 2         The texture of this concealer pallet is fantas...
# 3         I really can't tell what exactly this thing is...
# 4         It was a little smaller than I expected, but t...
#                                 ...
# 198497    Just a little dab of this shea butter should b...
# 198498    This shea butter is completely raw and unrefin...
# 198499    The skin is the body's largest organ and it ab...
# 198500    I have very dry elbows and knees.  I have a to...
# 198501    This is 100% pure Shea Butter. Do not mistake ...
# Name: reviewText, Length: 198502, dtype: object

# %%
df_meta = getDF('meta_All_Beauty.json.gz')
meta = df_meta[['title', 'description']]
meta
# Out:
#                                                    title  \
# 0          Loud 'N Clear&trade; Personal Sound Amplifier
# 1      No7 Lift &amp; Luminate Triple Action Serum 50...
# 2        No7 Stay Perfect Foundation Cool Vanilla by No7
# 3      Wella Koleston Perfect Hair Colour 44/44 Mediu...
# 4      Lacto Calamine Skin Balance Oil control 120 ml...
# ...                                                  ...
# 32887  Barielle Pro Textured Grip Cuticle Nipper, Purple
# 32888  (Buy 3 Get 1 Free) Salon Perfect Eye Makeup Co...
# 32889  NOW D-Mannose 500 mg - 120 Veg Capsules (Pack ...
# 32890  12 White Feather Shuttlecocks Birdies Badminto...
# 32891  FESHFEN Scrunchy Scrunchies Synthetic Hair Bun...
#
#                                              description
# 0      [Loud 'N Clear Personal Sound Amplifier allows...
# 1      [No7 Lift & Luminate Triple Action Serum 50ml ...
# 2      [No7 Stay Perfect Foundation now stays perfect...
# 3                                                     []
# 4      [Lacto Calamine Skin Balance Daily Nourishing ...
# ...                                                  ...
# 32887                                                 []
# 32888                                                 []
# 32889                                                 []
# 32890  [Brand new and high quality<br> Enables fast v...
# 32891                                                 []
#
# [32892 rows x 2 columns]

# %% [markdown]
# ### Реализация способа извлечения названий

# %%
all_nouns = []
is_noun = lambda pos: pos[:2] == 'NN'
for title_text in meta['title']:
    clean = re.sub("[^a-zA-Z]+", " ", title_text)
    tokenized = nltk.word_tokenize(clean)
    nouns = [all_nouns.append(word) for (word, pos) in nltk.pos_tag(tokenized) if is_noun(pos)]

# %% [markdown]
# Посмотрим на наиболее частые слова в описании: из наиболее содержательных можно выделить такие слова-товары как oil, cream, makeup, brush, gel, spray, soap, lotion, bag, powder, cosmetic, shampoo и так далее. Возьмем некоторые из этих слов при дальнейшей работе с векторизованным корпусом (cream и lotion могут встречаться в одном и том же контексте, поэтому нет смысла брать все эти слова).

# %%
c = Counter(all_nouns)
print(c.most_common(100))
# Out:
# [('Hair', 3799), ('Pack', 3464), ('oz', 2797), ('Set', 2224), ('Black', 2082), ('Body', 2032), ('Nail', 2003), ('amp', 1794), ('ml', 1785), ('Oil', 1606), ('Women', 1584), ('Skin', 1528), ('Cream', 1509), ('Color', 1459), ('Oz', 1405), ('Makeup', 1333), ('Brush', 1262), ('Gel', 1262), ('Natural', 1234), ('quot', 1233), ('Ounce', 1160), ('Lip', 1100), ('Spray', 980), ('Kit', 976), ('Face', 958), ('Soap', 956), ('White', 950), ('Eye', 906), ('Beauty', 900), ('Pink', 890), ('g', 838), ('Art', 820), ('Case', 819), ('New', 778), ('Free', 778), ('Lotion', 777), ('Anti', 755), ('Size', 745), ('Blue', 741), ('Bag', 740), ('Powder', 737), ('Fashion', 710), ('Men', 709), ('Care', 705), ('Silver', 699), ('Cosmetic', 666), ('Professional', 658), ('x', 636), ('Travel', 634), ('Bath', 632), ('Long', 631), ('Gold', 625), ('pcs', 624), ('Gift', 619), ('Shampoo', 606), ('Red', 603), ('Polish', 599), ('Hand', 589), ('Facial', 580), ('Mask', 579), ('Crystal', 554), ('Brown', 549), ('Organic', 532), ('Pure', 530), ('Light', 520), ('Wig', 519), ('Colors', 511), ('fl', 510), ('Clip', 508), ('Lipstick', 504), ('S', 496), ('Ring', 489), ('C', 482), ('A', 476), ('Treatment', 475), ('Bar', 471), ('Liquid', 461), ('Serum', 458), ('Style', 449), ('Collection', 444), ('D', 443), ('Rose', 442), ('s', 435), ('Dark', 435), ('OZ', 433), ('X', 432), ('All', 430), ('Tool', 429), ('Steel', 427), ('Eau', 419), ('Tattoo', 416), ('Wash', 412), ('Flower', 404), ('Full', 402), ('Clear', 401), ('L', 401), ('Soft', 400), ('Salon', 400), ('Bottle', 397), ('SPF', 395)]

# %%
def preprocessing(texts):
    corpus = []
    for text in texts:
        clean_text = re.sub('[^\w ]','',text).lower()
        sent = clean_text.split()
        corpus.append(sent)
    return corpus

# %%
corpus = preprocessing(reviews.tolist())
model = gensim.models.Word2Vec(corpus, window=5, sg=0)

# %%
model.wv.most_similar('shampoo', topn=15)
# Out:
# [('conditioner', 0.7603300213813782),
#  ('shampooconditioner', 0.7103340029716492),
#  ('shampoos', 0.678347647190094),
#  ('leavein', 0.6327095031738281),
#  ('product', 0.6241132616996765),
#  ('soap', 0.6173998117446899),
#  ('conditoner', 0.6079196929931641),
#  ('pantene', 0.6021020412445068),
#  ('detangler', 0.5967162251472473),
#  ('masque', 0.593921959400177),
#  ('cowash', 0.5650419592857361),
#  ('cleanser', 0.5531744360923767),
#  ('suave', 0.5469362139701843),
#  ('wen', 0.5389069318771362),
#  ('dove', 0.5372868180274963)]

# %%
model.wv.most_similar('product', topn=15)
# Out:
# [('item', 0.7884013056755066),
#  ('stuff', 0.7680280208587646),
#  ('productit', 0.704575777053833),
#  ('serum', 0.6579384207725525),
#  ('producti', 0.6500611305236816),
#  ('shampoo', 0.6241132020950317),
#  ('lotion', 0.6212374567985535),
#  ('straightener', 0.5980736017227173),
#  ('mascara', 0.5919773578643799),
#  ('cleanser', 0.5866108536720276),
#  ('tool', 0.5758373737335205),
#  ('oneit', 0.5612951517105103),
#  ('device', 0.5609607696533203),
#  ('moisturizer', 0.5597200989723206),
#  ('soap', 0.5572393536567688)]

# %% [markdown]
# Можно было бы найти пересечения названий товаров из метадаты и текстов отзывов, но 1) очень долго, тк надо перебирать два списка (они не равны по длине) 2) скорее всего это не принесет пользы, тк мы уже взяли из названий сущ-е, возможно из n-грамм образуются названия

# %%
# intersections = []
# all_titles = preprocessing(meta['title'].tolist())
# for title in tqdm(all_titles):
#     for text in corpus:
#         inter = set.intersection(set(title), set(text))
#         if inter:
#             intersections.append(' '.join(list(inter)))

# %% [markdown]
# Можно заметить, что в тех же контекстах что и product встречаются сами названия продуктов. Возьмем слова, полученные моделью от слова product

# %% [markdown]
# ### Выделение n-грамм

# %% [markdown]
# будем собирать n-граммы по полученным названиям продуктов в отзывах

# %%
words = ['item', 'stuff', 'serum', 'shampoo', 'lotion', 'straightener', 'mascara', 'cleanser', 'tool', 'device',
         'moisturizer', 'soap']

# %%
def full_preprocessing(text):
    clean_text = re.sub('[^\w ]','',text).lower()
    tokens = word_tokenize(clean_text)
    tokens_without_sw = [word for word in clean_text.split() if not word in stopwords]
    return tokens_without_sw

# %%
all_tokens = []
for text in tqdm(reviews):
    tokens = full_preprocessing(text)
    all_tokens.append(' '.join(tokens))
# Out:
#   0%|          | 0/198502 [00:00<?, ?it/s]

# %%
all_tokens = ' '.join(all_tokens).split()

# %%
def ngram_filter(word, n):
    all_ngrams = ngrams(all_tokens, n)
    filtered_ngrams = [x for x in all_ngrams if word in x]
    return filtered_ngrams

# %% [markdown]
# Биграммы с нужными нам словами

# %%
all_bigrams = {word : [] for word in words}
for word in words:
    bigrams = ngram_filter(word, 2)
    all_bigrams[word].append(bigrams)

# %%
for word in words:
    print('---')
    print('СЛОВО', word)
    print('---')
    for bg in all_bigrams[word]:
        for item in bg[:20]:
            print(' '.join(item))
# Out:
# ---
# СЛОВО item
# ---
# quality item
# item installed
# negative item
# item guess
# sized item
# item oily
# brand item
# item since
# used item
# item father
# sponge item
# item wish
# shelf item
# item looking
# unhappy item
# item oredered
# bought item
# item really
# recommend item
# item cetaphil
# ---
# СЛОВО stuff
# ---
# good stuff
# stuff 2
# campers stuff
# stuff great
# dried stuff
# stuff makes
# thick stuff
# stuff pumps
# amazing stuff
# stuff gotten
# like stuff
# stuff say
# good stuff
# stuff seasons
# trythis stuff
# stuff awful
# preference stuff
# stuff awful
# cleanser stuff
# stuff lasts
# ---
# СЛОВО serum
# ---
# antifrizz serum
# serum spray
# hair serum
# serum style
# regimen serum
# serum toner
# retinol serum
# serum see
# c serum
# serum timeless
# eye serum
# serum lol
# new serum
# serum moisturizer
# rx serum
# serum hydroquinone
# dmae serum
# serum also
# repair serum
# serum exfoliating
# ---
# СЛОВО shampoo
# ---
# disappointed shampoo
# shampoo conditioner
# thinnest shampoo
# shampoo ive
# oz shampoo
# shampoo used
# organics shampoo
# shampoo conditioner
# biotin shampoo
# shampoo shampoo
# shampoo harsh
# line shampoo
# shampoo conditioner
# overpowering shampoo
# shampoo lathers
# wthe shampoo
# shampoo conditioner
# use shampoo
# shampoo conditioner
# use shampoo
# ---
# СЛОВО lotion
# ---
# body lotion
# lotion body
# came lotion
# lotion nice
# soap lotion
# lotion shampoo
# conditionar lotion
# lotion etc
# fill lotion
# lotion instead
# strong lotion
# lotion prefer
# wonderful lotion
# lotion applied
# protect lotion
# lotion damage
# scratches lotion
# lotion never
# properties lotion
# lotion smell
# ---
# СЛОВО straightener
# ---
# minutes straightener
# straightener sucks
# curls straightener
# straightener flat
# using straightener
# straightener get
# got straightener
# straightener could
# hair straightener
# straightener lightweight
# owned straightener
# straightener 2
# love straightener
# straightener gets
# purchased straightener
# straightener shipped
# received straightener
# straightener thermal
# awesome straightener
# straightener great
# ---
# СЛОВО mascara
# ---
# duty mascara
# mascara liner
# best mascara
# mascara remover
# waterproof mascara
# mascara burn
# waterproof mascara
# mascara liner
# liner mascara
# mascara make
# removing mascara
# mascara great
# black mascara
# mascara rings
# ideal mascara
# mascara remover
# waterproof mascara
# mascara great
# eye mascara
# mascara also
# ---
# СЛОВО cleanser
# ---
# acid cleanser
# cleanser afterwardsi
# remover cleanser
# cleanser stuff
# dab cleanser
# cleanser wet
# face cleanser
# cleanser suuper
# favorite cleanser
# cleanser lather
# cetaphil cleanser
# cleanser buff
# facial cleanser
# cleanser helped
# foaming cleanser
# cleanser minor
# cream cleanser
# cleanser 67ounce
# nighttime cleanser
# cleanser gentle
# ---
# СЛОВО tool
# ---
# gardening tool
# tool couple
# using tool
# tool curling
# exfoliation tool
# tool must
# cleaning tool
# tool small
# online tool
# tool feria
# another tool
# tool step
# live tool
# tool using
# hair tool
# tool beauty
# wonderful tool
# tool even
# hair tool
# tool much
# ---
# СЛОВО device
# ---
# toning device
# device use
# foreign device
# device mix
# think device
# device works
# affective device
# device clears
# little device
# device spa
# using device
# device learned
# callus device
# device ball
# shape device
# device cradled
# squeeze device
# device inward
# objective device
# device tone
# ---
# СЛОВО moisturizer
# ---
# natural moisturizer
# moisturizer penetrates
# exceptional moisturizer
# moisturizer importantly
# scent moisturizer
# moisturizer works
# favorite moisturizer
# moisturizer definite
# add moisturizer
# moisturizer order
# foot moisturizer
# moisturizer feet
# instructions moisturizer
# moisturizer keep
# toner moisturizer
# moisturizer little
# far moisturizer
# moisturizer ive
# right moisturizer
# moisturizer would
# ---
# СЛОВО soap
# ---
# along soap
# soap actually
# dish soap
# soap like
# dish soap
# soap using
# put soap
# soap lotion
# kind soap
# soap shampoo
# level soap
# soap bottles
# bottle soap
# soap spare
# gel soap
# soap use
# enough soap
# soap quickly
# bar soap
# soap matteri

# %% [markdown]
# Триграммы с нужными нам словами

# %%
all_threegrams = {word : [] for word in words}
for word in words:
    threegrams = ngram_filter(word, 3)
    all_threegrams[word].append(threegrams)

# %%
for word in words:
    print('---')
    print('СЛОВО', word)
    print('---')
    for bg in all_threegrams[word]:
        for item in bg[:20]:
            print(' '.join(item))
# Out:
# ---
# СЛОВО item
# ---
# wellhigh quality item
# quality item installed
# item installed thing
# anything negative item
# negative item guess
# item guess working
# trave sized item
# sized item oily
# item oily formula
# store brand item
# brand item since
# item since price
# never used item
# used item father
# item father used
# soft sponge item
# sponge item wish
# item wish list
# stuff shelf item
# shelf item looking
# ---
# СЛОВО stuff
# ---
# money good stuff
# good stuff 2
# stuff 2 thumbs
# happy campers stuff
# campers stuff great
# stuff great first
# thicker dried stuff
# dried stuff makes
# stuff makes hair
# even thick stuff
# thick stuff pumps
# stuff pumps smoothly
# years amazing stuff
# amazing stuff gotten
# stuff gotten hands
# home like stuff
# like stuff say
# stuff say least
# sweet good stuff
# good stuff seasons
# ---
# СЛОВО serum
# ---
# potent antifrizz serum
# antifrizz serum spray
# serum spray strong
# mousse hair serum
# hair serum style
# serum style hair
# care regimen serum
# regimen serum toner
# serum toner moisturizer
# roc retinol serum
# retinol serum see
# serum see itll
# vitamin c serum
# c serum timeless
# serum timeless sunscreen
# nighttime eye serum
# eye serum lol
# serum lol keeps
# conjunction new serum
# new serum moisturizer
# ---
# СЛОВО shampoo
# ---
# pretty disappointed shampoo
# disappointed shampoo conditioner
# shampoo conditioner high
# surfactants thinnest shampoo
# thinnest shampoo ive
# shampoo ive ever
# 14 oz shampoo
# oz shampoo used
# shampoo used whole
# avalon organics shampoo
# organics shampoo conditioner
# shampoo conditioner months
# counterbalance biotin shampoo
# biotin shampoo shampoo
# shampoo shampoo harsh
# shampoo harsh effective
# lot line shampoo
# line shampoo conditioner
# shampoo conditioner one
# scent overpowering shampoo
# ---
# СЛОВО lotion
# ---
# introduce body lotion
# body lotion body
# lotion body cream
# offered came lotion
# came lotion nice
# lotion nice unexpected
# put soap lotion
# soap lotion shampoo
# lotion shampoo andconditioner
# soap conditionar lotion
# conditionar lotion etc
# lotion etc handy
# want fill lotion
# fill lotion instead
# lotion instead body
# smell strong lotion
# strong lotion prefer
# lotion prefer lighter
# feel wonderful lotion
# wonderful lotion applied
# ---
# СЛОВО straightener
# ---
# 10 minutes straightener
# minutes straightener sucks
# straightener sucks crimper
# perfect curls straightener
# curls straightener flat
# straightener flat iron
# faster using straightener
# using straightener get
# straightener get almost
# first got straightener
# got straightener could
# straightener could wear
# hairmore hair straightener
# hair straightener lightweight
# straightener lightweight solia
# longer owned straightener
# owned straightener 2
# straightener 2 years
# replacement love straightener
# love straightener gets
# ---
# СЛОВО mascara
# ---
# heavy duty mascara
# duty mascara liner
# mascara liner shadow
# others best mascara
# best mascara remover
# mascara remover ive
# including waterproof mascara
# waterproof mascara burn
# mascara burn eyes
# take waterproof mascara
# waterproof mascara liner
# mascara liner find
# remove liner mascara
# liner mascara make
# mascara make slips
# best removing mascara
# removing mascara great
# mascara great also
# see black mascara
# black mascara rings
# ---
# СЛОВО cleanser
# ---
# glycolic acid cleanser
# acid cleanser afterwardsi
# cleanser afterwardsi never
# makeup remover cleanser
# remover cleanser stuff
# cleanser stuff lasts
# use dab cleanser
# dab cleanser wet
# cleanser wet puff
# use face cleanser
# face cleanser suuper
# cleanser suuper gentle
# scrub favorite cleanser
# favorite cleanser lather
# cleanser lather try
# little cetaphil cleanser
# cetaphil cleanser buff
# cleanser buff dirtno
# customer facial cleanser
# facial cleanser helped
# ---
# СЛОВО tool
# ---
# hand gardening tool
# gardening tool couple
# tool couple packets
# hit using tool
# using tool curling
# tool curling iron
# perfect exfoliation tool
# exfoliation tool must
# tool must spring
# brush cleaning tool
# cleaning tool small
# tool small objects
# used online tool
# online tool feria
# tool feria website
# saving another tool
# another tool step
# tool step great
# love live tool
# live tool using
# ---
# СЛОВО device
# ---
# facial toning device
# toning device use
# device use approximately
# throwing foreign device
# foreign device mix
# device mix iud
# honestly think device
# think device works
# device works fine
# seems affective device
# affective device clears
# device clears pores
# much little device
# little device spa
# device spa paid
# skills using device
# using device learned
# device learned perfect
# 20 callus device
# callus device ball
# ---
# СЛОВО moisturizer
# ---
# created natural moisturizer
# natural moisturizer penetrates
# moisturizer penetrates skin
# oil exceptional moisturizer
# exceptional moisturizer importantly
# moisturizer importantly used
# favorite scent moisturizer
# scent moisturizer works
# moisturizer works great
# fragrances favorite moisturizer
# favorite moisturizer definite
# moisturizer definite scent
# skin add moisturizer
# add moisturizer order
# moisturizer order blend
# okeefes foot moisturizer
# foot moisturizer feet
# moisturizer feet stay
# read instructions moisturizer
# instructions moisturizer keep
# ---
# СЛОВО soap
# ---
# cream along soap
# along soap actually
# soap actually worked
# lemony dish soap
# dish soap like
# soap like dial
# repellant dish soap
# dish soap using
# soap using harsh
# greati put soap
# put soap lotion
# soap lotion shampoo
# different kind soap
# kind soap shampoo
# soap shampoo face
# check level soap
# level soap bottles
# soap bottles one
# replacement bottle soap
# bottle soap spare

# %% [markdown]
# Ранжирование n-грамм. Я использовала likelihood ratio, PMI и jaccard score. Стоп-слова я исключила, чтобы они не попадали в n-граммы. Частотный фильтр я взяла 15.

# %%
corpus_new = preprocessing(reviews.tolist())

# %%
clean_corpus = []
for text in corpus_new:
    clean_text = [word for word in text if not word in stopwords]
    text = ' '.join(clean_text)
    clean_corpus.append(text)

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(' '.join(clean_corpus).split())
finder.apply_freq_filter(15)

# %%
pmi = []
lh = []
jaccard = []
for word in words:
    lemma = lemmatizer.lemmatize(word)
    pmi_ratio = [item for item in finder.nbest(bigram_measures.pmi, 100000000000) if lemma in item][:100]
    pmi.append([' '.join(x) for x in pmi_ratio])
    lh_ratio = [item for item in finder.nbest(bigram_measures.likelihood_ratio, 100000000000) if lemma in item][:100]
    lh.append([' '.join(x) for x in lh_ratio])
    jd_ratio = [item for item in finder.nbest(bigram_measures.jaccard, 100000000000) if lemma in item][:100]
    jaccard.append([' '.join(x) for x in jd_ratio])

# %% [markdown]
# Результаты ранжирующих метрик:

# %%
lh
# Out:
# [['received item',
#   'purchased item',
#   'item arrived',
#   'purchase item',
#   'recommend item',
#   'bought item',
#   'item shipped',
#   'addon item',
#   'item came',
#   'item described',
#   'item free',
#   'return item',
#   'great item',
#   'quality item',
#   'purchasing item',
#   'luxury item',
#   'whether item',
#   'item amazon',
#   'item received',
#   'ordered item',
#   'receive item',
#   'particular item',
#   'returned item',
#   'add item',
#   'returning item',
#   'wrong item',
#   'buy item',
#   'item exactly',
#   'got item',
#   'item description',
#   'item hair',
#   'item today',
#   'hair item',
#   'pleased item',
#   'buying item',
#   'love item',
#   'shipping item',
#   'happy item',
#   'review item',
#   'item price',
#   'must item',
#   'saw item',
#   'beauty item',
#   'another item',
#   'product item',
#   'price item',
#   'item works',
#   'give item',
#   'reviews item',
#   'item ordered',
#   'item love',
#   'item purchased',
#   'item took',
#   'found item',
#   'item purchase',
#   'item would',
#   'item ive',
#   'find item',
#   'item great',
#   'item however',
#   'item thought',
#   'item could',
#   'item seems',
#   'good item',
#   'item got',
#   'using item',
#   'item didnt',
#   'used item',
#   'item made',
#   'one item',
#   'item use',
#   'item really',
#   'item bought',
#   'item like',
#   'item makes',
#   'first item',
#   'nice item',
#   'item used',
#   'item time',
#   'item im',
#   'item first',
#   'get item',
#   'item try',
#   'item recommend',
#   'item dont',
#   'use item',
#   'like item',
#   'item much',
#   'item well',
#   'item little',
#   'item doesnt',
#   'item one',
#   'item also',
#   'item good'],
#  ['love stuff',
#   'stuff works',
#   'stuff amazing',
#   'stuff smells',
#   'good stuff',
#   'stuff really',
#   'stuff awesome',
#   'stuff great',
#   'great stuff',
#   'stuff makes',
#   'loves stuff',
#   'expensive stuff',
#   'stuff rocks',
#   'amazing stuff',
#   'swear stuff',
#   'cheap stuff',
#   'diva stuff',
#   'wow stuff',
#   'using stuff',
#   'stuff made',
#   'stuff product',
#   'stuff doesnt',
#   'stuff bomb',
#   'buy stuff',
#   'stuff goes',
#   'best stuff',
#   'bad stuff',
#   'stuff seriously',
#   'white stuff',
#   'stuff lasts',
#   'stuff actually',
#   'stuff fantastic',
#   'put stuff',
#   'one stuff',
#   'ton stuff',
#   'stuff isnt',
#   'stuff truly',
#   'stuff ive',
#   'stuff keeps',
#   'stuff miracle',
#   'stuff seems',
#   'hooked stuff',
#   'stuff absolutely',
#   'stuff incredible',
#   'nasty stuff',
#   'awesome stuff',
#   'know stuff',
#   'buying stuff',
#   'stuff magic',
#   'stuff trick',
#   'try stuff',
#   'also stuff',
#   'stuff hair',
#   'stuff wonderful',
#   'stuff awful',
#   'stuff skin',
#   'stuff pretty',
#   'stuff definitely',
#   'cheaper stuff',
#   'bottles stuff',
#   'stuff helps',
#   'lot stuff',
#   'bottle stuff',
#   'putting stuff',
#   'stuff expensive',
#   'stuff worked',
#   'product stuff',
#   'stuff dry',
#   'stuff holds',
#   'stuff gets',
#   'like stuff',
#   'wonderful stuff',
#   'stuff stays',
#   'hate stuff',
#   'stuff im',
#   'stuff feels',
#   'loved stuff',
#   'stuff cleans',
#   'stuff comes',
#   'stuff ever',
#   'real stuff',
#   'stuff time',
#   'stuff best',
#   'stuff inside',
#   'stuff takes',
#   'stuff nothing',
#   'anyway stuff',
#   'stuff didnt',
#   'stuff wont',
#   'stuff leaves',
#   'stuff well',
#   'stuff highly',
#   'little stuff',
#   'old stuff',
#   'stuff totally',
#   'stuff bought',
#   'stuff hope',
#   'stuff must',
#   'stuff strong',
#   'bought stuff'],
#  ['c serum',
#   'acid serum',
#   'regenerating serum',
#   'using serum',
#   'glow serum',
#   'eye serum',
#   'lifting serum',
#   'guardian serum',
#   'infusing serum',
#   'antiaging serum',
#   'lift serum',
#   'skinny serum',
#   'regenerist serum',
#   'repair serum',
#   'hyaluronic serum',
#   'facial serum',
#   'smoothing serum',
#   'antifrizz serum',
#   'retinol serum',
#   'serum hyaluronic',
#   'serum works',
#   'serum contains',
#   'activating serum',
#   'apply serum',
#   'serum absorbs',
#   'ha serum',
#   'tightening serum',
#   'serum vitamin',
#   'applied serum',
#   'serum hair',
#   'serum growth',
#   'serum moisturizer',
#   'firming serum',
#   'serum perfective',
#   'potion serum',
#   'moisturizing serum',
#   'truth serum',
#   'serum comes',
#   'wrinkle serum',
#   'shine serum',
#   'use serum',
#   'firm serum',
#   'applying serum',
#   'serum goes',
#   'lash serum',
#   'love serum',
#   'serum face',
#   'concentrated serum',
#   'serum lightweight',
#   'serum daily',
#   'product serum',
#   'serum light',
#   'serum morning',
#   'aging serum',
#   'serum helps',
#   'cream serum',
#   'serum absorbed',
#   'creme serum',
#   'serum made',
#   'frizz serum',
#   'serum really',
#   'keratin serum',
#   'serum also',
#   'serum feels',
#   'serum twice',
#   'growth serum',
#   'toner serum',
#   'serum makes',
#   'serum eye',
#   'serum product',
#   'drops serum',
#   'serum night',
#   'serum help',
#   'serum ive',
#   'serum worked',
#   'serum first',
#   'serum 2',
#   'serum smells',
#   'serum along',
#   'serum applied',
#   'serum seems',
#   'moisturizer serum',
#   'gel serum',
#   'get serum',
#   'serum clear',
#   'serum serum',
#   'serum leaves',
#   'put serum',
#   'face serum',
#   'serum week',
#   'used serum',
#   'serum wonderful',
#   'serum apply',
#   'serum weeks',
#   'serum month',
#   'serum add',
#   'serum ever',
#   'serum review',
#   'night serum',
#   'serum gives'],
#  ['shampoo conditioner',
#   'clarifying shampoo',
#   'dry shampoo',
#   'antidandruff shampoo',
#   'dandruff shampoo',
#   'using shampoo',
#   'matching shampoo',
#   'regular shampoo',
#   'shampoo lathers',
#   'mud shampoo',
#   'nourishing shampoo',
#   'baby shampoo',
#   'shampoo 129',
#   'shampoo smells',
#   '1 shampoo',
#   'conditioner shampoo',
#   'shampoo condition',
#   'shampoo leaves',
#   'shampoo cleans',
#   'volumizing shampoo',
#   'fortifying shampoo',
#   'used shampoo',
#   'shampoo works',
#   '2in1 shampoo',
#   'shampoo conditioners',
#   'sulfatefree shampoo',
#   'suave shampoo',
#   'use shampoo',
#   'moisture shampoo',
#   'free shampoo',
#   'glossing shampoo',
#   'rejuvenating shampoo',
#   'shampoo left',
#   'companion shampoo',
#   'clear shampoo',
#   'shampoo matching',
#   'infusing shampoo',
#   'moisturizing shampoo',
#   'along shampoo',
#   'shampoo alone',
#   'care shampoo',
#   'shampoo product',
#   'preserving shampoo',
#   'shampoo lathered',
#   'milk shampoo',
#   'volume shampoo',
#   'infusion shampoo',
#   'keratin shampoo',
#   'would shampoo',
#   'normal shampoo',
#   'love shampoo',
#   'renewal shampoo',
#   'waterless shampoo',
#   'nourish shampoo',
#   'product shampoo',
#   'corresponding shampoo',
#   'dove shampoo',
#   'nexxus shampoo',
#   'conditioning shampoo',
#   'like shampoo',
#   'shampoo conditioneri',
#   'therappe shampoo',
#   'fekkai shampoo',
#   'tresemme shampoo',
#   'shampoo along',
#   'shampoo face',
#   'brand shampoo',
#   'biotin shampoo',
#   'pantene shampoo',
#   'favorite shampoo',
#   'mint shampoo',
#   'shampoo seems',
#   'shampoo twice',
#   'shampoo rinse',
#   'shampoo suave',
#   'purple shampoo',
#   'agedefy shampoo',
#   'thickening shampoo',
#   'shampoo 135',
#   'shampoo pleasant',
#   'separate shampoo',
#   'another shampoo',
#   'good shampoo',
#   'shampoo lather',
#   'rescue shampoo',
#   'therapy shampoo',
#   'basic shampoo',
#   'shampoo contains',
#   'sulfate shampoo',
#   'conjunction shampoo',
#   'amount shampoo',
#   'mens shampoo',
#   'naturals shampoo',
#   'scalp shampoo',
#   'bottles shampoo',
#   'shampoo 28',
#   'shampoo every',
#   'shampoo made',
#   'hydralight shampoo',
#   'bottle shampoo'],
#  ['body lotion',
#   'tanning lotion',
#   'moisturizing lotion',
#   'hand lotion',
#   'suntan lotion',
#   'sunscreen lotion',
#   'lotion spf',
#   'face lotion',
#   'put lotion',
#   'lotion smells',
#   'apply lotion',
#   'repair lotion',
#   'lotion goes',
#   'lotion hair',
#   'regular lotion',
#   'vaseline lotion',
#   'buffering lotion',
#   'like lotion',
#   'facial lotion',
#   'hair lotion',
#   'smoothing lotion',
#   'lotion absorbs',
#   'using lotion',
#   'tingle lotion',
#   'firming lotion',
#   'lotion moisturizes',
#   'love lotion',
#   'selftanning lotion',
#   'calamine lotion',
#   'putting lotion',
#   'product lotion',
#   'lotion hands',
#   'scented lotion',
#   'applying lotion',
#   'lotion light',
#   'moisture lotion',
#   'wrap lotion',
#   'repairing lotion',
#   'lotion works',
#   'lotion aloe',
#   'baby lotion',
#   'lotion feels',
#   'butter lotion',
#   'lotion product',
#   'soothing lotion',
#   'perfecting lotion',
#   'favorite lotion',
#   'lotion thick',
#   'lotion ive',
#   'healing lotion',
#   'lotion doesnt',
#   'tan lotion',
#   'setting lotion',
#   'spf lotion',
#   'lotion afterwards',
#   'cetaphil lotion',
#   'lotion sunscreen',
#   'lotion seems',
#   'lotion provides',
#   'bond lotion',
#   'lotion ever',
#   'lotion vaseline',
#   'lotion soaks',
#   'lotion face',
#   'shaving lotion',
#   'one lotion',
#   'use lotion',
#   'lotion lotion',
#   'lotion contains',
#   'day lotion',
#   'goto lotion',
#   'lotion body',
#   'sunblock lotion',
#   'nongreasy lotion',
#   'lightweight lotion',
#   'lotion leaves',
#   'unscented lotion',
#   'lotion makes',
#   'hydrating lotion',
#   'reapply lotion',
#   'lotion great',
#   'aveeno lotion',
#   'nivea lotion',
#   'lotion worked',
#   'thick lotion',
#   'bottle lotion',
#   'lotion isnt',
#   'lotion tanning',
#   'light lotion',
#   'creamy lotion',
#   'best lotion',
#   'drying lotion',
#   'lotion greasy',
#   'rubbing lotion',
#   'radiant lotion',
#   'applied lotion',
#   'cream lotion',
#   'lotion pleasant',
#   'lotion comes',
#   'lotion cream'],
#  ['hair straightener',
#   'straightener heats',
#   'remington straightener',
#   'straightener pearl',
#   'therapy straightener',
#   'ceramic straightener',
#   'chi straightener',
#   'old straightener',
#   'pro straightener',
#   'straightener works',
#   'using straightener',
#   'use straightener',
#   'straightener gets',
#   'straightener 1',
#   'straightener worked',
#   'iron straightener',
#   'straightener ive',
#   'dryer straightener',
#   'new straightener',
#   'straightener would',
#   'straightener doesnt',
#   'used straightener',
#   'love straightener',
#   'good straightener',
#   'straightener also',
#   'straightener really',
#   'great straightener',
#   'straightener used',
#   'straightener good',
#   'straightener well',
#   'straightener hair',
#   'like straightener',
#   'straightener great',
#   'straightener like'],
#  ['waterproof mascara',
#   'favorite mascara',
#   'mascara wand',
#   'remove mascara',
#   'applying mascara',
#   'blinc mascara',
#   'apply mascara',
#   'lashes mascara',
#   'love mascara',
#   'best mascara',
#   'mascara ive',
#   'eyeliner mascara',
#   'mascara eyeliner',
#   'wear mascara',
#   'black mascara',
#   'wearing mascara',
#   'lengthening mascara',
#   'removing mascara',
#   'washable mascara',
#   'mascara lashes',
#   'mascara ever',
#   'mascara doesnt',
#   'maybelline mascara',
#   'put mascara',
#   'mascara goes',
#   'regular mascara',
#   'mascara makes',
#   'mascara lengthens',
#   'lash mascara',
#   'nonwaterproof mascara',
#   'liner mascara',
#   'drugstore mascara',
#   'mascara clumps',
#   'clumps mascara',
#   'mascara black',
#   'mascara waterproof',
#   'falsies mascara',
#   'volumizing mascara',
#   'coats mascara',
#   'brown mascara',
#   'coat mascara',
#   'mascara clump',
#   'like mascara',
#   'mascara mascara',
#   'mascara gives',
#   'mascara brush',
#   'covergirl mascara',
#   'mascara junkie',
#   'tube mascara',
#   'including mascara',
#   'putting mascara',
#   'mascara stays',
#   'goto mascara',
#   'mascara clumpy',
#   'mascara eyelashes',
#   'mascara comes',
#   'worst mascara',
#   'product mascara',
#   'mascara eye',
#   'eyelashes mascara',
#   'mascara remover',
#   'another mascara',
#   'mascara years',
#   'mascara tube',
#   'volume mascara',
#   'mascara really',
#   'perfect mascara',
#   'brand mascara',
#   'new mascara',
#   'mascara primer',
#   'find mascara',
#   'without mascara',
#   'mascara never',
#   'mascara loreal',
#   'using mascara',
#   'mascara usually',
#   'mascara without',
#   'mascara works',
#   'types mascara',
#   'mascara dries',
#   'mascara bottom',
#   'old mascara',
#   'mascara product',
#   'type mascara',
#   'mascara definitely',
#   'take mascara',
#   'brands mascara',
#   'great mascara',
#   'mascara first',
#   'good mascara',
#   'mascara always',
#   'mascara everyday',
#   'mascara one',
#   'mascara awesome',
#   'mascara ok',
#   'clear mascara',
#   'natural mascara',
#   'primer mascara',
#   'mascara however',
#   'applied mascara'],
#  ['facial cleanser',
#   'foaming cleanser',
#   'exfoliating cleanser',
#   'gentle cleanser',
#   'cleanser toner',
#   'cream cleanser',
#   'face cleanser',
#   'cetaphil cleanser',
#   'cleanser gentle',
#   'renewal cleanser',
#   'power cleanser',
#   'daily cleanser',
#   'gel cleanser',
#   'cleanser works',
#   'detoxifying cleanser',
#   'ice cleanser',
#   'use cleanser',
#   'cleanser hair',
#   'using cleanser',
#   'cleanser removes',
#   'pore cleanser',
#   'hydrating cleanser',
#   'moisturizing cleanser',
#   'cleanser leaves',
#   'mild cleanser',
#   'hair cleanser',
#   'activated cleanser',
#   'cleanser doesnt',
#   'regular cleanser',
#   'biore cleanser',
#   'acne cleanser',
#   'foam cleanser',
#   'creamy cleanser',
#   'glycolic cleanser',
#   'conditioning cleanser',
#   'cleanser remove',
#   'cleanser morning',
#   'cleanser clarisonic',
#   'olay cleanser',
#   'cleanser ive',
#   'favorite cleanser',
#   'cleanser comes',
#   'cleanser cleans',
#   'good cleanser',
#   'cleanser scrub',
#   'cleanser mild',
#   'cleanser creamy',
#   'effective cleanser',
#   'cleanser foam',
#   'cleanser sensitive',
#   'cleanser product',
#   'best cleanser',
#   'love cleanser',
#   'deep cleanser',
#   'finish cleanser',
#   'cleanser left',
#   'cleanser came',
#   'acid cleanser',
#   'liquid cleanser',
#   'skin cleanser',
#   'another cleanser',
#   'cleanser ever',
#   'cleanser moisturizer',
#   'cleanser seems',
#   'amount cleanser',
#   'cleanser effective',
#   'cleanser made',
#   'scrub cleanser',
#   'cleanser face',
#   'cleanser instead',
#   'normal cleanser',
#   'used cleanser',
#   'cleanser really',
#   'cleanser cleanser',
#   'cleanser would',
#   'cleanser use',
#   'found cleanser',
#   'cleanser wont',
#   'cleanser perfect',
#   'cleanser every',
#   'cleanser night',
#   'cleanser amazing',
#   'cleanser takes',
#   'oil cleanser',
#   'cleanser isnt',
#   'cleanser smells',
#   'cleanser might',
#   'well cleanser',
#   'cleanser also',
#   'get cleanser',
#   'great cleanser',
#   'like cleanser',
#   'cleanser daily',
#   'cleanser nice',
#   'cleanser didnt',
#   'new cleanser',
#   'cleanser worked',
#   'cleanser well',
#   'cleanser used',
#   'cleanser light'],
#  ['styling tool',
#   'dotting tool',
#   'great tool',
#   'shower tool',
#   'little tool',
#   'beauty tool',
#   'tool works',
#   'hot tool',
#   'quality tool',
#   'tool makes',
#   'tool help',
#   'tool set',
#   'using tool',
#   'good tool',
#   'tool made',
#   'perfect tool',
#   'nice tool',
#   'love tool',
#   'use tool',
#   'tool hair',
#   'hair tool',
#   'tool use',
#   'tool would',
#   'tool great',
#   'one tool',
#   'tool ive',
#   'tool also',
#   'tool one',
#   'tool really',
#   'like tool',
#   'tool good',
#   'tool like'],
#  ['using device', 'little device', 'device works', 'use device'],
#  ['tinted moisturizer',
#   'daily moisturizer',
#   'facial moisturizer',
#   'moisturizer spf',
#   'good moisturizer',
#   'light moisturizer',
#   'moisturizer sunscreen',
#   'use moisturizer',
#   'apply moisturizer',
#   'regular moisturizer',
#   'daytime moisturizer',
#   'nighttime moisturizer',
#   'put moisturizer',
#   'night moisturizer',
#   'moisturizer afterwards',
#   'toner moisturizer',
#   'great moisturizer',
#   'follow moisturizer',
#   'antiaging moisturizer',
#   'oilfree moisturizer',
#   'dermacontrol moisturizer',
#   'applying moisturizer',
#   'moisturizer light',
#   'sunscreen moisturizer',
#   'hair moisturizer',
#   'moisturizer night',
#   'favorite moisturizer',
#   'body moisturizer',
#   'face moisturizer',
#   'rich moisturizer',
#   'using moisturizer',
#   'lightweight moisturizer',
#   'defying moisturizer',
#   'moisturizer face',
#   'additional moisturizer',
#   'moisturizer hair',
#   'excellent moisturizer',
#   'spf moisturizer',
#   'best moisturizer',
#   'moisturizer ive',
#   'moisturizer works',
#   'moisturizer underneath',
#   'basic moisturizer',
#   'serum moisturizer',
#   'moisturizer 42',
#   'olay moisturizer',
#   'moisturizer doesnt',
#   'moisturizer afterward',
#   'need moisturizer',
#   'followed moisturizer',
#   'moisturizer top',
#   'separate moisturizer',
#   'moisturizer morning',
#   'moisturizer foundation',
#   'product moisturizer',
#   'simple moisturizer',
#   'moisturizer absorbs',
#   'nightly moisturizer',
#   'effective moisturizer',
#   'usual moisturizer',
#   'moisturizer goes',
#   'moisturizer skin',
#   'moisturizer feels',
#   'nice moisturizer',
#   'layer moisturizer',
#   'heavier moisturizer',
#   'moisturizer contains',
#   'normal moisturizer',
#   'moisturizer sunblock',
#   'moisturizer also',
#   'moisturizer primer',
#   'hydrating moisturizer',
#   'tea moisturizer',
#   'oil moisturizer',
#   'applied moisturizer',
#   'skip moisturizer',
#   'day moisturizer',
#   'another moisturizer',
#   'cream moisturizer',
#   'putting moisturizer',
#   'heavy moisturizer',
#   'moisturizer bb',
#   'cetaphil moisturizer',
#   'gel moisturizer',
#   'decent moisturizer',
#   'moisturizer thats',
#   'moisturizer makeup',
#   'one moisturizer',
#   'moisturizer absorb',
#   'moisturizer would',
#   'moisturizer ever',
#   'lip moisturizer',
#   'mix moisturizer',
#   'moisturizer keeps',
#   'free moisturizer',
#   'adding moisturizer',
#   'moisturizer applying',
#   'moisturizer cream',
#   'moisturizer product',
#   'moisturizer first'],
#  ['bar soap',
#   'hand soap',
#   'black soap',
#   'dove soap',
#   'dish soap',
#   'soap water',
#   'liquid soap',
#   'castile soap',
#   'using soap',
#   'soap bar',
#   'soap dispenser',
#   'mud soap',
#   'soap scum',
#   'soap smells',
#   'soap dish',
#   'bars soap',
#   'soap lathers',
#   'salt soap',
#   'antibacterial soap',
#   'soap dispensers',
#   'ivory soap',
#   'soap bars',
#   'regular soap',
#   'sulfur soap',
#   'soap hair',
#   'mild soap',
#   'foaming soap',
#   'love soap',
#   'soap nuts',
#   'laundry soap',
#   'bath soap',
#   'soap cleans',
#   'soap soap',
#   'use soap',
#   'facial soap',
#   'wash soap',
#   'soap body',
#   'body soap',
#   'product soap',
#   'soap leaves',
#   'soap dispensed',
#   'soap gentle',
#   'soap product',
#   'soap suds',
#   'soap doesnt',
#   'soap shower',
#   'soap works',
#   'soap wash',
#   'soap lather',
#   'soap washcloth',
#   'spring soap',
#   'like soap',
#   'soap comes',
#   'soap refill',
#   'moisturizing soap',
#   'glycerin soap',
#   'soap container',
#   'soap face',
#   'milk soap',
#   'amount soap',
#   'mineral soap',
#   'foam soap',
#   'plain soap',
#   'soap residue',
#   'tree soap',
#   'scented soap',
#   'soap wonderful',
#   'soaps soap',
#   'washing soap',
#   'soap contains',
#   'soap pump',
#   'oil soap',
#   'soap lasts',
#   'soap mild',
#   'smelling soap',
#   'soap drying',
#   'soap dove',
#   'lather soap',
#   'easily soap',
#   'soap made',
#   'soap liquid',
#   'soap also',
#   'natural soap',
#   'favorite soap',
#   'gentle soap',
#   'used soap',
#   'soap makes',
#   'soap system',
#   'soap warm',
#   'shower soap',
#   'soap ever',
#   'recommend soap',
#   'soap skin',
#   'also soap',
#   'soap helped',
#   'time soap',
#   'soap seems',
#   'soap pleasant',
#   'dry soap',
#   'soap hand']]

# %%
pmi
# Out:
# [['addon item',
#   'luxury item',
#   'item shipped',
#   'returning item',
#   'item arrived',
#   'item described',
#   'returned item',
#   'return item',
#   'received item',
#   'purchased item',
#   'receive item',
#   'whether item',
#   'purchasing item',
#   'purchase item',
#   'item description',
#   'particular item',
#   'wrong item',
#   'item came',
#   'item today',
#   'item free',
#   'bought item',
#   'ordered item',
#   'item received',
#   'item exactly',
#   'add item',
#   'quality item',
#   'recommend item',
#   'shipping item',
#   'item amazon',
#   'pleased item',
#   'saw item',
#   'must item',
#   'buying item',
#   'beauty item',
#   'review item',
#   'item ordered',
#   'happy item',
#   'buy item',
#   'got item',
#   'item took',
#   'another item',
#   'reviews item',
#   'item purchased',
#   'great item',
#   'give item',
#   'item purchase',
#   'item price',
#   'found item',
#   'price item',
#   'item works',
#   'item thought',
#   'item seems',
#   'love item',
#   'item however',
#   'find item',
#   'item could',
#   'item got',
#   'item made',
#   'item love',
#   'item ive',
#   'item didnt',
#   'item bought',
#   'item would',
#   'item great',
#   'item makes',
#   'using item',
#   'good item',
#   'used item',
#   'first item',
#   'one item',
#   'item really',
#   'nice item',
#   'item first',
#   'item time',
#   'item im',
#   'item try',
#   'item recommend',
#   'get item',
#   'item dont',
#   'use item',
#   'item well',
#   'item doesnt',
#   'item also',
#   'item one',
#   'item good',
#   'item little',
#   'item much',
#   'like item',
#   'item used',
#   'item like',
#   'item use',
#   'product item',
#   'hair item',
#   'item hair'],
#  ['diva stuff',
#   'stuff rocks',
#   'stuff bomb',
#   'swear stuff',
#   'stuff amazing',
#   'stuff awesome',
#   'loves stuff',
#   'hooked stuff',
#   'love stuff',
#   'wow stuff',
#   'stuff incredible',
#   'nasty stuff',
#   'stuff seriously',
#   'ton stuff',
#   'stuff works',
#   'stuff smells',
#   'stuff magic',
#   'stuff trick',
#   'stuff awful',
#   'stuff miracle',
#   'cheap stuff',
#   'stuff fantastic',
#   'stuff truly',
#   'expensive stuff',
#   'stuff makes',
#   'stuff holds',
#   'amazing stuff',
#   'stuff keeps',
#   'stuff cleans',
#   'stuff lasts',
#   'good stuff',
#   'white stuff',
#   'hate stuff',
#   'stuff inside',
#   'bottles stuff',
#   'putting stuff',
#   'cheaper stuff',
#   'awesome stuff',
#   'stuff absolutely',
#   'stuff really',
#   'bad stuff',
#   'anyway stuff',
#   'stuff stays',
#   'stuff made',
#   'stuff great',
#   'stuff goes',
#   'buying stuff',
#   'stuff isnt',
#   'stuff totally',
#   'smelling stuff',
#   'great stuff',
#   'stuff wonderful',
#   'loved stuff',
#   'stuff hope',
#   'stuff actually',
#   'best stuff',
#   'real stuff',
#   'stuff helps',
#   'stuff supposed',
#   'wonderful stuff',
#   'stuff seems',
#   'stuff gets',
#   'buy stuff',
#   'stuff worked',
#   'stuff okay',
#   'stuff doesnt',
#   'stuff helped',
#   'stuff takes',
#   'stuff expensive',
#   'sticky stuff',
#   'stuff ok',
#   'stuff dries',
#   'put stuff',
#   'stuff must',
#   'know stuff',
#   'stuff comes',
#   'tube stuff',
#   'tell stuff',
#   'stuff says',
#   'stuff ever',
#   'stuff gives',
#   'believe stuff',
#   'stuff wont',
#   'old stuff',
#   'stuff nothing',
#   'stuff definitely',
#   'using stuff',
#   'kind stuff',
#   'stuff highly',
#   'stuff pretty',
#   'stuff strong',
#   'stuff leaves',
#   'lot stuff',
#   'stuff feels',
#   'store stuff',
#   'try stuff',
#   'bottle stuff',
#   'stuff ive',
#   'stuff wish',
#   'recommended stuff'],
#  ['regenerating serum',
#   'guardian serum',
#   'c serum',
#   'activating serum',
#   'infusing serum',
#   'antifrizz serum',
#   'skinny serum',
#   'lifting serum',
#   'serum perfective',
#   'ha serum',
#   'acid serum',
#   'potion serum',
#   'tightening serum',
#   'regenerist serum',
#   'truth serum',
#   'antiaging serum',
#   'firming serum',
#   'lift serum',
#   'retinol serum',
#   'glow serum',
#   'hyaluronic serum',
#   'repair serum',
#   'smoothing serum',
#   'serum hyaluronic',
#   'concentrated serum',
#   'firm serum',
#   'wrinkle serum',
#   'serum contains',
#   'serum growth',
#   'lash serum',
#   'serum absorbs',
#   'serum lightweight',
#   'aging serum',
#   'eye serum',
#   'serum absorbed',
#   'keratin serum',
#   'creme serum',
#   'facial serum',
#   'serum vitamin',
#   'growth serum',
#   'toner serum',
#   'applied serum',
#   'drops serum',
#   'moisturizing serum',
#   'shine serum',
#   'frizz serum',
#   'applying serum',
#   'serum daily',
#   'serum twice',
#   'serum comes',
#   'apply serum',
#   'using serum',
#   'serum moisturizer',
#   'serum morning',
#   'serum helps',
#   'serum along',
#   'serum goes',
#   'serum works',
#   'serum applied',
#   'serum worked',
#   'serum night',
#   'serum made',
#   'serum feels',
#   'serum light',
#   'serum eye',
#   'serum help',
#   'serum month',
#   'cream serum',
#   'serum clear',
#   'serum add',
#   'serum wonderful',
#   'serum serum',
#   'serum makes',
#   'serum gives',
#   'gel serum',
#   'serum seems',
#   'serum three',
#   'serum leaves',
#   'serum let',
#   'serum 2',
#   'moisturizer serum',
#   'serum face',
#   'serum week',
#   'serum weeks',
#   'serum review',
#   'serum smells',
#   'wonderful serum',
#   'serum ever',
#   'love serum',
#   'serum noticed',
#   'serum nothing',
#   'night serum',
#   'serum decided',
#   'serum several',
#   'serum fragrance',
#   'serum also',
#   'clear serum',
#   'serum apply',
#   'amount serum',
#   'serum first'],
#  ['clarifying shampoo',
#   'shampoo 129',
#   'therappe shampoo',
#   'antidandruff shampoo',
#   'fortifying shampoo',
#   'preserving shampoo',
#   'waterless shampoo',
#   'agedefy shampoo',
#   'matching shampoo',
#   'corresponding shampoo',
#   'infusing shampoo',
#   'companion shampoo',
#   'sulfatefree shampoo',
#   'shampoo 135',
#   'rejuvenating shampoo',
#   '2in1 shampoo',
#   'shampoo conditioneri',
#   'shampoo conditioner',
#   'glossing shampoo',
#   'nourishing shampoo',
#   'mud shampoo',
#   'volumizing shampoo',
#   'dandruff shampoo',
#   'shampoo lathered',
#   'hydralight shampoo',
#   'shampoo lathers',
#   'medicated shampoo',
#   'rescue shampoo',
#   'nourish shampoo',
#   'biotin shampoo',
#   'shampoo matching',
#   'renewal shampoo',
#   'shampoo 28',
#   'thickening shampoo',
#   'fekkai shampoo',
#   'milk shampoo',
#   'shampoo cleans',
#   'baby shampoo',
#   'infusion shampoo',
#   'regular shampoo',
#   'shampoo leaked',
#   'shampoo condition',
#   'mens shampoo',
#   'nexxus shampoo',
#   'naturals shampoo',
#   'tresemme shampoo',
#   'mint shampoo',
#   'conjunction shampoo',
#   'shampoo conditioners',
#   'suave shampoo',
#   'frieda shampoo',
#   'keratin shampoo',
#   'basic shampoo',
#   'pantene shampoo',
#   'shampoo suds',
#   'separate shampoo',
#   'shampoo alone',
#   '1 shampoo',
#   'sulfate shampoo',
#   'therapy shampoo',
#   'shampoo combined',
#   'picky shampoo',
#   'cleanse shampoo',
#   'shampoo promises',
#   'shampoo conjunction',
#   'whenever shampoo',
#   'strength shampoo',
#   'along shampoo',
#   'shampoo tresemme',
#   'purple shampoo',
#   'shampoo cleaned',
#   'conditioning shampoo',
#   'moisture shampoo',
#   'dry shampoo',
#   'volume shampoo',
#   'shampoo leaves',
#   'tree shampoo',
#   'dove shampoo',
#   'smoothing shampoo',
#   'shampoo suave',
#   'shampoo contains',
#   'shoulders shampoo',
#   'repair shampoo',
#   'moisturizing shampoo',
#   'normal shampoo',
#   'particular shampoo',
#   'shampoo lather',
#   'free shampoo',
#   'shampoo along',
#   'usual shampoo',
#   'shampoo smells',
#   'shampoo rinse',
#   'decent shampoo',
#   'average shampoo',
#   'shampoo rinsed',
#   'clear shampoo',
#   'shampoo bar',
#   'rinsing shampoo',
#   'shampoo sulfate',
#   'bottles shampoo'],
#  ['buffering lotion',
#   'calamine lotion',
#   'suntan lotion',
#   'selftanning lotion',
#   'tanning lotion',
#   'perfecting lotion',
#   'repairing lotion',
#   'firming lotion',
#   'body lotion',
#   'tingle lotion',
#   'bond lotion',
#   'vaseline lotion',
#   'repair lotion',
#   'smoothing lotion',
#   'lotion spf',
#   'moisturizing lotion',
#   'goto lotion',
#   'lotion moisturizes',
#   'hand lotion',
#   'nivea lotion',
#   'wrap lotion',
#   'sunscreen lotion',
#   'nongreasy lotion',
#   'scented lotion',
#   'healing lotion',
#   'cetaphil lotion',
#   'lotion soaks',
#   'lotion aloe',
#   'sunblock lotion',
#   'soothing lotion',
#   'lotion absorbs',
#   'radiant lotion',
#   'unscented lotion',
#   'lotion vaseline',
#   'aveeno lotion',
#   'reapply lotion',
#   'lotion afterwards',
#   'hydrating lotion',
#   'shaving lotion',
#   'putting lotion',
#   'baby lotion',
#   'basic lotion',
#   'lotion provides',
#   'regular lotion',
#   'setting lotion',
#   'rubbing lotion',
#   'facial lotion',
#   'lightweight lotion',
#   'tan lotion',
#   'lotion tanning',
#   'lotion contains',
#   'butter lotion',
#   'moisture lotion',
#   'lotion goes',
#   'lotion absorbed',
#   'applying lotion',
#   'lotion smells',
#   'apply lotion',
#   'put lotion',
#   'spf lotion',
#   'lotion pure',
#   'lotion lightweight',
#   'lotion legs',
#   'face lotion',
#   'creamy lotion',
#   'favorite lotion',
#   'lotion hands',
#   'smelling lotion',
#   'lotion sunscreen',
#   'lotion creamy',
#   'rich lotion',
#   'mixed lotion',
#   'consistency lotion',
#   'everyday lotion',
#   'particular lotion',
#   'lotion moisturize',
#   'glow lotion',
#   'lotion pleasant',
#   'lotion consistency',
#   'lotion feet',
#   'lotion truly',
#   'mix lotion',
#   'version lotion',
#   'thicker lotion',
#   'lotion feels',
#   'drying lotion',
#   'lotion keeps',
#   'lotion light',
#   'applied lotion',
#   'lotion ever',
#   'lotion seems',
#   'lotion worked',
#   '15 lotion',
#   'rub lotion',
#   'normal lotion',
#   'hate lotion',
#   'lotion thick',
#   'lotion vitamin',
#   'lotion simply',
#   'lotion moisturizing'],
#  ['straightener pearl',
#   'remington straightener',
#   'straightener heats',
#   'chi straightener',
#   'ceramic straightener',
#   'pro straightener',
#   'therapy straightener',
#   'old straightener',
#   'straightener 1',
#   'straightener gets',
#   'straightener worked',
#   'dryer straightener',
#   'hair straightener',
#   'iron straightener',
#   'straightener works',
#   'new straightener',
#   'using straightener',
#   'straightener ive',
#   'use straightener',
#   'straightener doesnt',
#   'straightener would',
#   'used straightener',
#   'straightener also',
#   'love straightener',
#   'good straightener',
#   'straightener really',
#   'straightener used',
#   'great straightener',
#   'straightener good',
#   'straightener well',
#   'like straightener',
#   'straightener hair',
#   'straightener great',
#   'straightener like'],
#  ['blinc mascara',
#   'nonwaterproof mascara',
#   'waterproof mascara',
#   'washable mascara',
#   'lengthening mascara',
#   'mascara lengthens',
#   'falsies mascara',
#   'mascara wand',
#   'covergirl mascara',
#   'mascara junkie',
#   'mascara clumps',
#   'maybelline mascara',
#   'volumizing mascara',
#   'clumps mascara',
#   'goto mascara',
#   'mascara clump',
#   'mascara clumpy',
#   'removing mascara',
#   'eyeliner mascara',
#   'mascara eyeliner',
#   'remove mascara',
#   'lash mascara',
#   'drugstore mascara',
#   'mascara waterproof',
#   'liner mascara',
#   'favorite mascara',
#   'worst mascara',
#   'wearing mascara',
#   'applying mascara',
#   'including mascara',
#   'lashes mascara',
#   'black mascara',
#   'coats mascara',
#   'mascara eyelashes',
#   'eyelashes mascara',
#   'mascara remover',
#   'wear mascara',
#   'mascara lashes',
#   'putting mascara',
#   'regular mascara',
#   'brown mascara',
#   'apply mascara',
#   'mascara stays',
#   'tube mascara',
#   'mascara loreal',
#   'mascara black',
#   'types mascara',
#   'mascara ever',
#   'coat mascara',
#   'best mascara',
#   'mascara gives',
#   'volume mascara',
#   'mascara bottom',
#   'mascara tube',
#   'mascara goes',
#   'mascara primer',
#   'mascara mascara',
#   'put mascara',
#   'mascara everyday',
#   'mascara dries',
#   'mascara makes',
#   'mascara comes',
#   'mascara ive',
#   'brands mascara',
#   'type mascara',
#   'brand mascara',
#   'primer mascara',
#   'mascara doesnt',
#   'another mascara',
#   'mascara run',
#   'mascara ok',
#   'mascara eye',
#   'love mascara',
#   'mascara awesome',
#   'new mascara',
#   'mascara usually',
#   'old mascara',
#   'mascara years',
#   'perfect mascara',
#   'cheap mascara',
#   'mascara brush',
#   'applied mascara',
#   'take mascara',
#   'clear mascara',
#   'mascara favorite',
#   'find mascara',
#   'mascara never',
#   'without mascara',
#   'mascara definitely',
#   'store mascara',
#   'mascara without',
#   'mascara isnt',
#   'mascara went',
#   'mascara always',
#   'mascara however',
#   'mascara wear',
#   'eyes mascara',
#   'natural mascara',
#   'mascara wont',
#   'mascara seems'],
#  ['detoxifying cleanser',
#   'foaming cleanser',
#   'activated cleanser',
#   'facial cleanser',
#   'ice cleanser',
#   'renewal cleanser',
#   'exfoliating cleanser',
#   'cetaphil cleanser',
#   'cleanser toner',
#   'gentle cleanser',
#   'cleanser removes',
#   'pore cleanser',
#   'biore cleanser',
#   'hydrating cleanser',
#   'glycolic cleanser',
#   'power cleanser',
#   'cleanser gentle',
#   'cleanser clarisonic',
#   'mild cleanser',
#   'foam cleanser',
#   'daily cleanser',
#   'cleanser cleans',
#   'conditioning cleanser',
#   'cleanser foam',
#   'creamy cleanser',
#   'moisturizing cleanser',
#   'cleanser mild',
#   'gel cleanser',
#   'olay cleanser',
#   'cleanser creamy',
#   'cream cleanser',
#   'regular cleanser',
#   'cleanser scrub',
#   'cleanser remove',
#   'finish cleanser',
#   'cleanser leaves',
#   'effective cleanser',
#   'acid cleanser',
#   'liquid cleanser',
#   'cleanser morning',
#   'favorite cleanser',
#   'acne cleanser',
#   'deep cleanser',
#   'scrub cleanser',
#   'face cleanser',
#   'cleanser comes',
#   'cleanser effective',
#   'cleanser works',
#   'normal cleanser',
#   'cleanser left',
#   'cleanser came',
#   'cleanser instead',
#   'cleanser sensitive',
#   'cleanser doesnt',
#   'another cleanser',
#   'cleanser ever',
#   'cleanser cleanser',
#   'amount cleanser',
#   'best cleanser',
#   'cleanser takes',
#   'using cleanser',
#   'cleanser seems',
#   'cleanser moisturizer',
#   'cleanser wont',
#   'cleanser daily',
#   'cleanser ive',
#   'cleanser might',
#   'cleanser night',
#   'cleanser made',
#   'cleanser isnt',
#   'cleanser amazing',
#   'cleanser worked',
#   'use cleanser',
#   'cleanser perfect',
#   'found cleanser',
#   'new cleanser',
#   'cleanser every',
#   'good cleanser',
#   'line cleanser',
#   'cleanser smells',
#   'love cleanser',
#   'cleanser oily',
#   'cleanser feels',
#   'cleanser found',
#   'oil cleanser',
#   'cleanser face',
#   'cleanser far',
#   'body cleanser',
#   'cleanser shower',
#   'cleanser light',
#   'cleanser didnt',
#   'used cleanser',
#   'perfect cleanser',
#   'cleanser would',
#   'cleanser nice',
#   'cleanser really',
#   'skin cleanser',
#   'soap cleanser',
#   'cleanser makes',
#   'cleanser definitely'],
#  ['dotting tool',
#   'styling tool',
#   'shower tool',
#   'beauty tool',
#   'hot tool',
#   'little tool',
#   'tool set',
#   'quality tool',
#   'tool help',
#   'great tool',
#   'tool works',
#   'tool makes',
#   'perfect tool',
#   'tool made',
#   'nice tool',
#   'using tool',
#   'good tool',
#   'love tool',
#   'tool would',
#   'use tool',
#   'tool ive',
#   'one tool',
#   'tool great',
#   'tool use',
#   'tool also',
#   'hair tool',
#   'tool one',
#   'tool really',
#   'tool good',
#   'tool like',
#   'like tool',
#   'tool hair'],
#  ['device works', 'little device', 'using device', 'use device'],
#  ['tinted moisturizer',
#   'dermacontrol moisturizer',
#   'nighttime moisturizer',
#   'defying moisturizer',
#   'daytime moisturizer',
#   'moisturizer 42',
#   'oilfree moisturizer',
#   'moisturizer spf',
#   'facial moisturizer',
#   'daily moisturizer',
#   'antiaging moisturizer',
#   'moisturizer afterward',
#   'nightly moisturizer',
#   'additional moisturizer',
#   'moisturizer afterwards',
#   'moisturizer underneath',
#   'basic moisturizer',
#   'follow moisturizer',
#   'toner moisturizer',
#   'lightweight moisturizer',
#   'skip moisturizer',
#   'moisturizer sunscreen',
#   'separate moisturizer',
#   'moisturizer sunblock',
#   'heavier moisturizer',
#   'followed moisturizer',
#   'rich moisturizer',
#   'regular moisturizer',
#   'cetaphil moisturizer',
#   'hydrating moisturizer',
#   'light moisturizer',
#   'usual moisturizer',
#   'applying moisturizer',
#   'tea moisturizer',
#   'spf moisturizer',
#   'apply moisturizer',
#   'moisturizer absorb',
#   'olay moisturizer',
#   'layer moisturizer',
#   'excellent moisturizer',
#   'moisturizer absorbs',
#   'moisturizer contains',
#   'sunscreen moisturizer',
#   'simple moisturizer',
#   'night moisturizer',
#   'adding moisturizer',
#   'favorite moisturizer',
#   'effective moisturizer',
#   'decent moisturizer',
#   'moisturizer night',
#   'put moisturizer',
#   'moisturizer bb',
#   'moisturizer primer',
#   'good moisturizer',
#   'putting moisturizer',
#   'normal moisturizer',
#   'effects moisturizer',
#   'serum moisturizer',
#   'moisturizer morning',
#   'mix moisturizer',
#   'moisturizer alone',
#   'body moisturizer',
#   'lip moisturizer',
#   'moisturizer immediately',
#   'based moisturizer',
#   'moisturizer keeps',
#   'moisturizer foundation',
#   'moisturizer combination',
#   'moisturizer light',
#   'applied moisturizer',
#   'moisturizer top',
#   'best moisturizer',
#   'heavy moisturizer',
#   'everyday moisturizer',
#   'moisturizer olay',
#   'moisturizer summer',
#   'moisturizer added',
#   'extra moisturizer',
#   'moisturizer goes',
#   'moisturizer applying',
#   'add moisturizer',
#   'creamy moisturizer',
#   'free moisturizer',
#   'moisturizer winter',
#   'another moisturizer',
#   'use moisturizer',
#   'moisturizer feels',
#   'need moisturizer',
#   'wonderful moisturizer',
#   'moisturizer thats',
#   'moisturizer helped',
#   'gel moisturizer',
#   'moisturizer sun',
#   'primer moisturizer',
#   'moisturizer works',
#   'along moisturizer',
#   'control moisturizer',
#   'moisturizer worked',
#   'moisturizer ever',
#   'cleanser moisturizer'],
#  ['soap scum',
#   'castile soap',
#   'dish soap',
#   'bar soap',
#   'soap dispensers',
#   'antibacterial soap',
#   'soap dish',
#   'soap nuts',
#   'ivory soap',
#   'sulfur soap',
#   'laundry soap',
#   'bars soap',
#   'soap dispensed',
#   'soap dispenser',
#   'soap bars',
#   'dove soap',
#   'mud soap',
#   'hand soap',
#   'black soap',
#   'foaming soap',
#   'liquid soap',
#   'salt soap',
#   'soap bar',
#   'soap lathers',
#   'soap washcloth',
#   'soap refill',
#   'soap suds',
#   'soap water',
#   'glycerin soap',
#   'soap cleans',
#   'milk soap',
#   'mild soap',
#   'plain soap',
#   'spring soap',
#   'bath soap',
#   'regular soap',
#   'tree soap',
#   'scented soap',
#   'soaps soap',
#   'foam soap',
#   'soap lather',
#   'mineral soap',
#   'soap smells',
#   'soap container',
#   'facial soap',
#   'soap gentle',
#   'soap contains',
#   'soap mild',
#   'smelling soap',
#   'soap residue',
#   'soap system',
#   'lather soap',
#   'soap soap',
#   'soap pump',
#   'soap dove',
#   'moisturizing soap',
#   'soap warm',
#   'washing soap',
#   'soap leaves',
#   'using soap',
#   'soap liquid',
#   'soap shower',
#   'soap body',
#   'soap comes',
#   'soap helped',
#   'wash soap',
#   'body soap',
#   'soap lasts',
#   'soap wonderful',
#   'gentle soap',
#   'amount soap',
#   'soap drying',
#   'pump soap',
#   'soap pleasant',
#   'normal soap',
#   'soap rinse',
#   'favorite soap',
#   'soap wash',
#   'butter soap',
#   'easily soap',
#   'soap dries',
#   'love soap',
#   'soap moisturizing',
#   'soap hand',
#   'soap excellent',
#   'soap doesnt',
#   'soap ever',
#   'soap gets',
#   'soap works',
#   'shower soap',
#   'soap strong',
#   'soap made',
#   'soap past',
#   'soap instead',
#   'soap anyone',
#   'soap fragrance',
#   'soap seems',
#   'natural soap',
#   'soap free',
#   'soap helps']]

# %%
jaccard
# Out:
# [['item arrived',
#   'received item',
#   'purchased item',
#   'purchase item',
#   'item shipped',
#   'item described',
#   'addon item',
#   'item came',
#   'return item',
#   'bought item',
#   'purchasing item',
#   'whether item',
#   'item free',
#   'recommend item',
#   'luxury item',
#   'quality item',
#   'item received',
#   'ordered item',
#   'receive item',
#   'particular item',
#   'item amazon',
#   'wrong item',
#   'returned item',
#   'add item',
#   'returning item',
#   'item exactly',
#   'item description',
#   'item today',
#   'pleased item',
#   'shipping item',
#   'buying item',
#   'buy item',
#   'got item',
#   'must item',
#   'review item',
#   'great item',
#   'saw item',
#   'happy item',
#   'beauty item',
#   'another item',
#   'item ordered',
#   'reviews item',
#   'item price',
#   'item took',
#   'item purchased',
#   'give item',
#   'price item',
#   'item works',
#   'love item',
#   'found item',
#   'item purchase',
#   'item thought',
#   'find item',
#   'item however',
#   'item love',
#   'item seems',
#   'item could',
#   'item ive',
#   'item got',
#   'item would',
#   'item made',
#   'item didnt',
#   'item great',
#   'good item',
#   'using item',
#   'item bought',
#   'used item',
#   'one item',
#   'item really',
#   'item makes',
#   'first item',
#   'nice item',
#   'item time',
#   'item im',
#   'item first',
#   'get item',
#   'item dont',
#   'item try',
#   'item recommend',
#   'use item',
#   'item well',
#   'item one',
#   'item doesnt',
#   'item also',
#   'item good',
#   'like item',
#   'item little',
#   'item much',
#   'item like',
#   'item used',
#   'item use',
#   'product item',
#   'hair item',
#   'item hair'],
#  ['love stuff',
#   'stuff amazing',
#   'stuff works',
#   'stuff smells',
#   'stuff awesome',
#   'good stuff',
#   'stuff makes',
#   'stuff really',
#   'stuff great',
#   'great stuff',
#   'loves stuff',
#   'expensive stuff',
#   'amazing stuff',
#   'stuff made',
#   'stuff doesnt',
#   'cheap stuff',
#   'using stuff',
#   'buy stuff',
#   'best stuff',
#   'stuff goes',
#   'bad stuff',
#   'put stuff',
#   'white stuff',
#   'stuff actually',
#   'wow stuff',
#   'stuff ive',
#   'stuff lasts',
#   'stuff isnt',
#   'stuff seems',
#   'know stuff',
#   'try stuff',
#   'stuff pretty',
#   'bottle stuff',
#   'stuff definitely',
#   'lot stuff',
#   'swear stuff',
#   'like stuff',
#   'stuff im',
#   'buying stuff',
#   'stuff absolutely',
#   'stuff keeps',
#   'stuff fantastic',
#   'stuff feels',
#   'stuff wonderful',
#   'stuff expensive',
#   'stuff love',
#   'stuff like',
#   'stuff rocks',
#   'use stuff',
#   'awesome stuff',
#   'stuff didnt',
#   'stuff seriously',
#   'stuff best',
#   'stuff worked',
#   'stuff helps',
#   'stuff truly',
#   'smell stuff',
#   'stuff ever',
#   'stuff bought',
#   'stuff gets',
#   'stuff comes',
#   'bought stuff',
#   'wonderful stuff',
#   'used stuff',
#   'get stuff',
#   'stuff dont',
#   'way stuff',
#   'better stuff',
#   'stuff used',
#   'stuff thick',
#   'say stuff',
#   'without stuff',
#   'cheaper stuff',
#   'stuff leaves',
#   'stuff miracle',
#   'stuff use',
#   'stuff nothing',
#   'stuff put',
#   'stuff face',
#   'stuff got',
#   'stuff highly',
#   'much stuff',
#   'give stuff',
#   'bottles stuff',
#   'recommend stuff',
#   'stuff work',
#   'stuff wont',
#   'right stuff',
#   'putting stuff',
#   'think stuff',
#   'old stuff',
#   'stuff strong',
#   'stuff stays',
#   'loved stuff',
#   'ton stuff',
#   'stuff would',
#   'stuff takes',
#   'stuff years',
#   'stuff perfect',
#   'stuff cant'],
#  ['c serum',
#   'acid serum',
#   'glow serum',
#   'regenerating serum',
#   'eye serum',
#   'antiaging serum',
#   'lifting serum',
#   'lift serum',
#   'repair serum',
#   'hyaluronic serum',
#   'facial serum',
#   'using serum',
#   'regenerist serum',
#   'infusing serum',
#   'smoothing serum',
#   'guardian serum',
#   'serum contains',
#   'serum hyaluronic',
#   'skinny serum',
#   'retinol serum',
#   'serum absorbs',
#   'apply serum',
#   'serum vitamin',
#   'applied serum',
#   'serum works',
#   'serum moisturizer',
#   'moisturizing serum',
#   'serum growth',
#   'serum comes',
#   'shine serum',
#   'antifrizz serum',
#   'applying serum',
#   'serum goes',
#   'tightening serum',
#   'serum daily',
#   'ha serum',
#   'wrinkle serum',
#   'lash serum',
#   'firming serum',
#   'serum morning',
#   'serum helps',
#   'serum lightweight',
#   'firm serum',
#   'serum light',
#   'cream serum',
#   'serum face',
#   'serum made',
#   'activating serum',
#   'serum feels',
#   'frizz serum',
#   'love serum',
#   'serum twice',
#   'serum perfective',
#   'serum makes',
#   'potion serum',
#   'truth serum',
#   'serum eye',
#   'aging serum',
#   'serum absorbed',
#   'concentrated serum',
#   'serum also',
#   'serum night',
#   'use serum',
#   'creme serum',
#   'toner serum',
#   'serum really',
#   'serum help',
#   'keratin serum',
#   'growth serum',
#   'serum 2',
#   'serum worked',
#   'serum first',
#   'serum smells',
#   'serum ive',
#   'serum seems',
#   'moisturizer serum',
#   'drops serum',
#   'serum applied',
#   'gel serum',
#   'put serum',
#   'serum leaves',
#   'serum serum',
#   'serum clear',
#   'serum apply',
#   'serum week',
#   'serum along',
#   'face serum',
#   'serum weeks',
#   'used serum',
#   'serum wonderful',
#   'serum ever',
#   'night serum',
#   'serum review',
#   'serum easy',
#   'serum cream',
#   'serum month',
#   'serum noticed',
#   'serum add',
#   'conditioner serum',
#   'serum nothing'],
#  ['shampoo conditioner',
#   'dry shampoo',
#   'regular shampoo',
#   'dandruff shampoo',
#   'using shampoo',
#   'clarifying shampoo',
#   'antidandruff shampoo',
#   'shampoo lathers',
#   'matching shampoo',
#   'shampoo smells',
#   'conditioner shampoo',
#   'shampoo works',
#   'used shampoo',
#   'shampoo leaves',
#   '1 shampoo',
#   'mud shampoo',
#   'baby shampoo',
#   'nourishing shampoo',
#   'shampoo condition',
#   'use shampoo',
#   'shampoo left',
#   'love shampoo',
#   'shampoo cleans',
#   'free shampoo',
#   'clear shampoo',
#   'like shampoo',
#   'moisture shampoo',
#   'shampoo conditioners',
#   'good shampoo',
#   'moisturizing shampoo',
#   'care shampoo',
#   'suave shampoo',
#   'shampoo ive',
#   'shampoo hair',
#   'shampoo really',
#   'shampoo doesnt',
#   'bottle shampoo',
#   'volumizing shampoo',
#   'shampoo seems',
#   'shampoo every',
#   'along shampoo',
#   'scent shampoo',
#   'shampoo would',
#   'shampoo made',
#   'try shampoo',
#   'brand shampoo',
#   'another shampoo',
#   'bought shampoo',
#   'tried shampoo',
#   'shampoo nice',
#   'normal shampoo',
#   'recommend shampoo',
#   'best shampoo',
#   'volume shampoo',
#   'shampoo also',
#   'favorite shampoo',
#   'great shampoo',
#   'amount shampoo',
#   'shampoo used',
#   'shampoo shampoo',
#   'shampoo thick',
#   'scalp shampoo',
#   'shampoo week',
#   'shampoo alone',
#   'shampoo 129',
#   'shampoo makes',
#   'shampoo good',
#   'found shampoo',
#   'shampoo didnt',
#   'hair shampoo',
#   'shampoo ever',
#   'new shampoo',
#   'dove shampoo',
#   'shampoo twice',
#   'shampoo along',
#   'shampoo first',
#   'smell shampoo',
#   'shampoo pleasant',
#   'buy shampoo',
#   'shampoo bottle',
#   'nice shampoo',
#   'quality shampoo',
#   'fortifying shampoo',
#   'conditioning shampoo',
#   'shampoo worked',
#   'shampoo great',
#   'shampoo rinse',
#   'find shampoo',
#   '2in1 shampoo',
#   'shampoo matching',
#   'line shampoo',
#   'shampoo use',
#   'keratin shampoo',
#   'shine shampoo',
#   'sulfatefree shampoo',
#   'shampoo leave',
#   'shampoo suave',
#   'shampoo one',
#   'shampoo lather',
#   'oil shampoo'],
#  ['body lotion',
#   'tanning lotion',
#   'moisturizing lotion',
#   'hand lotion',
#   'sunscreen lotion',
#   'lotion spf',
#   'face lotion',
#   'put lotion',
#   'lotion smells',
#   'apply lotion',
#   'lotion goes',
#   'suntan lotion',
#   'regular lotion',
#   'facial lotion',
#   'repair lotion',
#   'using lotion',
#   'lotion absorbs',
#   'lotion light',
#   'lotion hands',
#   'vaseline lotion',
#   'like lotion',
#   'love lotion',
#   'applying lotion',
#   'lotion works',
#   'moisture lotion',
#   'lotion feels',
#   'putting lotion',
#   'smoothing lotion',
#   'lotion thick',
#   'lotion doesnt',
#   'lotion ive',
#   'lotion moisturizes',
#   'favorite lotion',
#   'lotion seems',
#   'lotion face',
#   'tingle lotion',
#   'baby lotion',
#   'day lotion',
#   'scented lotion',
#   'lotion lotion',
#   'butter lotion',
#   'lotion ever',
#   'lotion sunscreen',
#   'lotion body',
#   'lotion makes',
#   'lotion great',
#   'use lotion',
#   'bottle lotion',
#   'thick lotion',
#   'light lotion',
#   'best lotion',
#   'spf lotion',
#   'wrap lotion',
#   'lotion leaves',
#   'firming lotion',
#   'cream lotion',
#   'lotion nice',
#   'lotion aloe',
#   'tan lotion',
#   'lotion cream',
#   'lotion would',
#   'lotion greasy',
#   'lotion also',
#   'lotion worked',
#   'lotion isnt',
#   'lotion scent',
#   'setting lotion',
#   'recommend lotion',
#   'lotion comes',
#   'good lotion',
#   'drying lotion',
#   'soothing lotion',
#   'lotion really',
#   'applied lotion',
#   'great lotion',
#   'lotion smell',
#   'smell lotion',
#   'nice lotion',
#   'lotion perfect',
#   'lotion every',
#   'used lotion',
#   'scent lotion',
#   'lotion afterwards',
#   'lotion actually',
#   'lotion shower',
#   'lotion im',
#   'lotion pleasant',
#   'lotion contains',
#   'lotion provides',
#   'lotion first',
#   'lotion moisturizing',
#   'buy lotion',
#   'lotion applied',
#   'creamy lotion',
#   'healing lotion',
#   'lotion wonderful',
#   'lotion didnt',
#   'lotion amazing',
#   'bought lotion',
#   'lotion night'],
#  ['straightener heats',
#   'remington straightener',
#   'straightener pearl',
#   'ceramic straightener',
#   'therapy straightener',
#   'chi straightener',
#   'pro straightener',
#   'old straightener',
#   'straightener 1',
#   'straightener gets',
#   'hair straightener',
#   'straightener worked',
#   'dryer straightener',
#   'iron straightener',
#   'straightener works',
#   'new straightener',
#   'using straightener',
#   'straightener ive',
#   'use straightener',
#   'straightener doesnt',
#   'straightener would',
#   'used straightener',
#   'straightener also',
#   'love straightener',
#   'good straightener',
#   'straightener really',
#   'straightener used',
#   'great straightener',
#   'straightener good',
#   'straightener well',
#   'like straightener',
#   'straightener hair',
#   'straightener great',
#   'straightener like'],
#  ['waterproof mascara',
#   'favorite mascara',
#   'mascara wand',
#   'remove mascara',
#   'applying mascara',
#   'lashes mascara',
#   'apply mascara',
#   'eyeliner mascara',
#   'mascara eyeliner',
#   'wearing mascara',
#   'black mascara',
#   'wear mascara',
#   'best mascara',
#   'mascara lashes',
#   'removing mascara',
#   'blinc mascara',
#   'mascara ever',
#   'regular mascara',
#   'mascara ive',
#   'mascara goes',
#   'lash mascara',
#   'put mascara',
#   'love mascara',
#   'maybelline mascara',
#   'mascara makes',
#   'mascara black',
#   'liner mascara',
#   'mascara doesnt',
#   'drugstore mascara',
#   'coat mascara',
#   'brown mascara',
#   'coats mascara',
#   'lengthening mascara',
#   'mascara mascara',
#   'mascara waterproof',
#   'mascara gives',
#   'tube mascara',
#   'mascara clumps',
#   'washable mascara',
#   'putting mascara',
#   'mascara stays',
#   'clumps mascara',
#   'mascara comes',
#   'mascara brush',
#   'volumizing mascara',
#   'mascara eye',
#   'mascara clump',
#   'including mascara',
#   'mascara lengthens',
#   'mascara eyelashes',
#   'another mascara',
#   'mascara years',
#   'mascara remover',
#   'eyelashes mascara',
#   'brand mascara',
#   'new mascara',
#   'perfect mascara',
#   'mascara tube',
#   'volume mascara',
#   'falsies mascara',
#   'find mascara',
#   'mascara never',
#   'worst mascara',
#   'without mascara',
#   'like mascara',
#   'mascara primer',
#   'covergirl mascara',
#   'mascara junkie',
#   'mascara usually',
#   'nonwaterproof mascara',
#   'mascara without',
#   'old mascara',
#   'take mascara',
#   'mascara definitely',
#   'mascara works',
#   'goto mascara',
#   'mascara really',
#   'mascara clumpy',
#   'type mascara',
#   'mascara dries',
#   'mascara first',
#   'brands mascara',
#   'mascara always',
#   'using mascara',
#   'mascara loreal',
#   'natural mascara',
#   'mascara bottom',
#   'great mascara',
#   'good mascara',
#   'mascara however',
#   'clear mascara',
#   'types mascara',
#   'every mascara',
#   'mascara awesome',
#   'mascara one',
#   'mascara everyday',
#   'applied mascara',
#   'eyes mascara',
#   'mascara bought',
#   'mascara ok'],
#  ['facial cleanser',
#   'foaming cleanser',
#   'exfoliating cleanser',
#   'gentle cleanser',
#   'cleanser toner',
#   'cleanser gentle',
#   'cetaphil cleanser',
#   'power cleanser',
#   'daily cleanser',
#   'renewal cleanser',
#   'cream cleanser',
#   'gel cleanser',
#   'moisturizing cleanser',
#   'face cleanser',
#   'mild cleanser',
#   'cleanser removes',
#   'hydrating cleanser',
#   'pore cleanser',
#   'cleanser leaves',
#   'cleanser works',
#   'regular cleanser',
#   'ice cleanser',
#   'acne cleanser',
#   'creamy cleanser',
#   'foam cleanser',
#   'cleanser remove',
#   'cleanser doesnt',
#   'cleanser morning',
#   'conditioning cleanser',
#   'favorite cleanser',
#   'olay cleanser',
#   'detoxifying cleanser',
#   'biore cleanser',
#   'using cleanser',
#   'cleanser comes',
#   'cleanser scrub',
#   'cleanser clarisonic',
#   'cleanser creamy',
#   'cleanser cleans',
#   'activated cleanser',
#   'effective cleanser',
#   'cleanser mild',
#   'glycolic cleanser',
#   'deep cleanser',
#   'cleanser sensitive',
#   'finish cleanser',
#   'cleanser left',
#   'use cleanser',
#   'best cleanser',
#   'cleanser foam',
#   'cleanser ive',
#   'cleanser came',
#   'acid cleanser',
#   'liquid cleanser',
#   'another cleanser',
#   'cleanser ever',
#   'good cleanser',
#   'amount cleanser',
#   'cleanser seems',
#   'cleanser moisturizer',
#   'love cleanser',
#   'cleanser made',
#   'cleanser instead',
#   'cleanser effective',
#   'cleanser cleanser',
#   'scrub cleanser',
#   'normal cleanser',
#   'found cleanser',
#   'cleanser face',
#   'cleanser perfect',
#   'cleanser every',
#   'cleanser wont',
#   'cleanser night',
#   'skin cleanser',
#   'used cleanser',
#   'cleanser amazing',
#   'cleanser would',
#   'cleanser really',
#   'cleanser smells',
#   'oil cleanser',
#   'cleanser isnt',
#   'cleanser might',
#   'cleanser takes',
#   'cleanser also',
#   'cleanser didnt',
#   'cleanser nice',
#   'new cleanser',
#   'cleanser use',
#   'cleanser daily',
#   'cleanser worked',
#   'cleanser light',
#   'great cleanser',
#   'cleanser feels',
#   'cleanser found',
#   'cleanser used',
#   'like cleanser',
#   'recommend cleanser',
#   'body cleanser',
#   'cleanser makes',
#   'cleanser oily'],
#  ['dotting tool',
#   'styling tool',
#   'shower tool',
#   'beauty tool',
#   'hot tool',
#   'little tool',
#   'great tool',
#   'quality tool',
#   'tool set',
#   'tool works',
#   'tool help',
#   'tool makes',
#   'perfect tool',
#   'tool made',
#   'nice tool',
#   'using tool',
#   'good tool',
#   'love tool',
#   'tool would',
#   'use tool',
#   'one tool',
#   'tool great',
#   'tool use',
#   'tool ive',
#   'tool also',
#   'hair tool',
#   'tool one',
#   'tool really',
#   'tool good',
#   'tool like',
#   'like tool',
#   'tool hair'],
#  ['device works', 'little device', 'using device', 'use device'],
#  ['tinted moisturizer',
#   'daily moisturizer',
#   'facial moisturizer',
#   'moisturizer spf',
#   'light moisturizer',
#   'moisturizer sunscreen',
#   'regular moisturizer',
#   'apply moisturizer',
#   'good moisturizer',
#   'put moisturizer',
#   'night moisturizer',
#   'daytime moisturizer',
#   'toner moisturizer',
#   'applying moisturizer',
#   'use moisturizer',
#   'moisturizer afterwards',
#   'nighttime moisturizer',
#   'moisturizer night',
#   'sunscreen moisturizer',
#   'favorite moisturizer',
#   'follow moisturizer',
#   'moisturizer light',
#   'body moisturizer',
#   'antiaging moisturizer',
#   'great moisturizer',
#   'best moisturizer',
#   'rich moisturizer',
#   'excellent moisturizer',
#   'face moisturizer',
#   'spf moisturizer',
#   'serum moisturizer',
#   'moisturizer works',
#   'using moisturizer',
#   'moisturizer face',
#   'lightweight moisturizer',
#   'moisturizer ive',
#   'need moisturizer',
#   'moisturizer doesnt',
#   'moisturizer top',
#   'olay moisturizer',
#   'moisturizer foundation',
#   'moisturizer morning',
#   'oilfree moisturizer',
#   'moisturizer goes',
#   'moisturizer feels',
#   'nice moisturizer',
#   'additional moisturizer',
#   'effective moisturizer',
#   'simple moisturizer',
#   'oil moisturizer',
#   'moisturizer absorbs',
#   'day moisturizer',
#   'cream moisturizer',
#   'moisturizer also',
#   'moisturizer underneath',
#   'another moisturizer',
#   'basic moisturizer',
#   'applied moisturizer',
#   'moisturizer skin',
#   'moisturizer makeup',
#   'normal moisturizer',
#   'heavy moisturizer',
#   'gel moisturizer',
#   'usual moisturizer',
#   'moisturizer thats',
#   'followed moisturizer',
#   'moisturizer would',
#   'moisturizer primer',
#   'layer moisturizer',
#   'moisturizer cream',
#   'moisturizer ever',
#   'moisturizer first',
#   'separate moisturizer',
#   'dermacontrol moisturizer',
#   'moisturizer contains',
#   'moisturizer didnt',
#   'moisturizer makes',
#   'putting moisturizer',
#   'love moisturizer',
#   'free moisturizer',
#   'defying moisturizer',
#   'moisturizer seems',
#   'moisturizer afterward',
#   'moisturizer use',
#   'moisturizer worked',
#   'moisturizer applying',
#   'moisturizer apply',
#   'moisturizer bb',
#   'wonderful moisturizer',
#   'tea moisturizer',
#   'cleanser moisturizer',
#   'moisturizer cant',
#   'lip moisturizer',
#   'moisturizer isnt',
#   'add moisturizer',
#   'moisturizer keeps',
#   'moisturizer smells',
#   'decent moisturizer',
#   'moisturizer used',
#   'moisturizer im'],
#  ['bar soap',
#   'hand soap',
#   'black soap',
#   'dove soap',
#   'soap water',
#   'liquid soap',
#   'dish soap',
#   'soap bar',
#   'soap dispenser',
#   'soap smells',
#   'mud soap',
#   'soap lathers',
#   'regular soap',
#   'salt soap',
#   'using soap',
#   'castile soap',
#   'bars soap',
#   'soap dish',
#   'soap bars',
#   'mild soap',
#   'ivory soap',
#   'antibacterial soap',
#   'bath soap',
#   'soap soap',
#   'soap cleans',
#   'facial soap',
#   'wash soap',
#   'soap scum',
#   'foaming soap',
#   'love soap',
#   'soap body',
#   'soap dispensers',
#   'sulfur soap',
#   'body soap',
#   'soap leaves',
#   'soap shower',
#   'soap gentle',
#   'soap doesnt',
#   'soap wash',
#   'soap works',
#   'soap comes',
#   'use soap',
#   'moisturizing soap',
#   'amount soap',
#   'laundry soap',
#   'soap face',
#   'soap lather',
#   'soap nuts',
#   'like soap',
#   'oil soap',
#   'soap container',
#   'soap wonderful',
#   'soap made',
#   'soap residue',
#   'natural soap',
#   'soap also',
#   'easily soap',
#   'soap makes',
#   'washing soap',
#   'used soap',
#   'soap lasts',
#   'recommend soap',
#   'soap drying',
#   'mineral soap',
#   'soap suds',
#   'shower soap',
#   'spring soap',
#   'soap pump',
#   'soap ever',
#   'favorite soap',
#   'foam soap',
#   'face soap',
#   'soap smell',
#   'soap seems',
#   'soap really',
#   'soap shampoo',
#   'soap great',
#   'soap contains',
#   'best soap',
#   'gentle soap',
#   'soap strong',
#   'soap dove',
#   'soap liquid',
#   'soap hand',
#   'soap mild',
#   'soap leave',
#   'soap years',
#   'tree soap',
#   'lather soap',
#   'scented soap',
#   'milk soap',
#   'soap fragrance',
#   'smelling soap',
#   'bought soap',
#   'soap still',
#   'soap washcloth',
#   'glycerin soap',
#   'smell soap',
#   'soaps soap',
#   'soap would']]

# %% [markdown]
# Тк по всем метрикам результаты вышли похожими, можно выделить их пересечения как итоговый вариант. Посмотрим на результаты триграмм, а затем выведем итоговые результаты.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(' '.join(clean_corpus).split())
finder.apply_freq_filter(15)

# %%
pmi_3 = []
lh_3 = []
jaccard_3 = []
for word in words:
    lemma = lemmatizer.lemmatize(word)
    pmi_ratio = [item for item in finder.nbest(trigram_measures.pmi, 100000000000) if lemma in item][:100]
    pmi_3.append([' '.join(x) for x in pmi_ratio])
    lh_ratio = [item for item in finder.nbest(trigram_measures.likelihood_ratio, 100000000000) if lemma in item][:100]
    lh_3.append([' '.join(x) for x in lh_ratio])
    jd_ratio = [item for item in finder.nbest(trigram_measures.jaccard, 100000000000) if lemma in item][:100]
    jaccard_3.append([' '.join(x) for x in jd_ratio])

# %%
pmi_3
# Out:
# [['item free discount',
#   'matter whether item',
#   'whether item free',
#   'item arrived quickly',
#   'received item free',
#   'item arrived time',
#   'highly recommend item',
#   'would recommend item'],
#  ['stuff works wonders',
#   'absolutely love stuff',
#   'stuff smells amazing',
#   'best stuff ever',
#   'stuff highly recommend',
#   'stuff lasts long',
#   'highly recommend stuff',
#   'stuff works great',
#   'stuff goes long',
#   'stuff smells great',
#   'give stuff try',
#   'stuff really works',
#   'stuff smells good',
#   'hair loves stuff',
#   'long way stuff',
#   'started using stuff',
#   'stuff works well',
#   'love stuff smells',
#   'dont know stuff',
#   'stuff little goes',
#   'love stuff makes',
#   'stuff dont know',
#   'stuff works better',
#   'using stuff years',
#   'pretty good stuff',
#   'stuff makes hair',
#   'stuff makes face',
#   'stuff smells like',
#   'sensitive skin stuff',
#   'love love stuff',
#   'stuff pretty good',
#   'love stuff works',
#   'stuff makes skin',
#   'stuff ive using',
#   'love stuff ive',
#   'stuff works really',
#   'stuff made hair',
#   'stuff ive used',
#   'ive using stuff',
#   'love stuff use',
#   'really love stuff',
#   'really like stuff',
#   'love stuff im',
#   'love stuff great',
#   'love stuff love',
#   'really good stuff',
#   'love stuff really',
#   'love stuff using',
#   'love stuff much',
#   'well love stuff',
#   'stuff really good',
#   'love stuff used',
#   'love stuff dont',
#   'great stuff love',
#   'product love stuff',
#   'hair stuff works',
#   'skin love stuff',
#   'hair love stuff',
#   'love stuff like',
#   'good stuff like',
#   'love stuff hair'],
#  ['serum perfective ceuticals',
#   'guardian serum growth',
#   'age guardian serum',
#   'vitamin c serum',
#   'vit c serum',
#   'hyaluronic acid serum',
#   'daily regenerating serum',
#   'anti aging serum',
#   'lift firm serum',
#   'mineral lift serum',
#   'smooth infusing serum',
#   'super skinny serum',
#   'heat potion serum',
#   'eye lifting serum',
#   'olay regenerist serum',
#   'serum hyaluronic acid',
#   'c serum hyaluronic',
#   'serum vitamin c',
#   'even glow serum',
#   'serum absorbs quickly',
#   'skin tightening serum',
#   'serum fragrance free',
#   'c serum face',
#   'serum twice day',
#   'serum 2 weeks',
#   'serum eye cream',
#   'c serum really',
#   'started using serum',
#   'serum works well',
#   'ive using serum',
#   'serum works great',
#   'serum ive used',
#   'serum makes skin',
#   'serum ive using',
#   'really like serum'],
#  ['shampoo 129 fluid',
#   'nourishing shampoo 129',
#   'renewal rejuvenating shampoo',
#   'cleanse nourish shampoo',
#   'youth renewal shampoo',
#   'therapy antidandruff shampoo',
#   'sea mud shampoo',
#   'johnsons baby shampoo',
#   'dandruff fortifying shampoo',
#   'platinum strength shampoo',
#   'rainforest fresh shampoo',
#   'oxygen moisture shampoo',
#   'boost nourishing shampoo',
#   'moroccan infusion shampoo',
#   'weightless moisture shampoo',
#   'sulfate free shampoo',
#   'smooth infusing shampoo',
#   'anti dandruff shampoo',
#   'end rescue shampoo',
#   'tea tree shampoo',
#   'color preserving shampoo',
#   'shampoo suave professionals',
#   'along matching shampoo',
#   'waterless dry shampoo',
#   '1 antidandruff shampoo',
#   'infusion shine shampoo',
#   'control nourishing shampoo',
#   'shampoo lathers nicely',
#   'batiste dry shampoo',
#   '2in1 shampoo conditioner',
#   'clarifying shampoo week',
#   'antidandruff shampoo conditioner',
#   'shampoo matching conditioner',
#   'head shoulders shampoo',
#   'shampoo conditioner combo',
#   'care nourishing shampoo',
#   'scalp nourishing shampoo',
#   '2 1 shampoo',
#   'scalp therapy shampoo',
#   'conditioner matching shampoo',
#   'keratin smooth shampoo',
#   'frizz control shampoo',
#   'use clarifying shampoo',
#   'matching shampoo conditioner',
#   'nourishing shampoo conditioner',
#   '1 shampoo plus',
#   'separate shampoo conditioner',
#   '1 shampoo conditioner',
#   'using clarifying shampoo',
#   'shampoo lathers well',
#   '3 1 shampoo',
#   'shampoo conditioner together',
#   'keratin shampoo conditioner',
#   'face whenever shampoo',
#   'combination shampoo conditioner',
#   'shampoo color treated',
#   'dandruff shampoo conditioner',
#   'shampoo plus conditioner',
#   'shampoo twice week',
#   'bottles shampoo conditioner',
#   'shampoo cleans well',
#   'regular shampoo conditioner',
#   'argan oil shampoo',
#   'color care shampoo',
#   'suave dry shampoo',
#   'shampoo conditioner combination',
#   'shampoo conditioner styling',
#   'shampoo along conditioner',
#   'use matching shampoo',
#   'clear scalp shampoo',
#   'small amount shampoo',
#   'hair milk shampoo',
#   'shampoo doesnt lather',
#   'conditioner along shampoo',
#   'shampoo body wash',
#   'back regular shampoo',
#   'best shampoo ever',
#   'clear shampoo conditioner',
#   'shampoo conditioner body',
#   'moisturizing shampoo conditioner',
#   'highly recommend shampoo',
#   'purchased shampoo conditioner',
#   'using shampoo conditioner',
#   'shampoo every day',
#   'shampoo conditioner line',
#   'shampoo conditioner left',
#   'decided try shampoo',
#   'recommend shampoo anyone',
#   'shampoo pleasant smell',
#   'body wash shampoo',
#   'shampoo conditioner set',
#   'shampoo ive ever',
#   'free shampoo conditioner',
#   'care shampoo conditioner',
#   'shampoo conditioner leaves',
#   'shampoo conditioner leave',
#   'shampoo cleans hair',
#   'shampoo smells amazing',
#   'use dandruff shampoo',
#   'brand shampoo conditioner'],
#  ['lotion pure oat',
#   'coolzone sunscreen lotion',
#   'gold bond lotion',
#   'cocoa radiant lotion',
#   'foaming wrap lotion',
#   'self tanning lotion',
#   'age repair lotion',
#   'hydrate sunscreen lotion',
#   'cocoa butter lotion',
#   'lotion spf 30',
#   'infusion body lotion',
#   'lotion spf 15',
#   'gentle soothing lotion',
#   'radiant body lotion',
#   'lotion aloe fresh',
#   'sunscreen lotion spf',
#   'vaseline body lotion',
#   'like suntan lotion',
#   'spf 15 lotion',
#   'shea butter lotion',
#   'body lotion aloe',
#   'lotion absorbs quickly',
#   'lotion goes smoothly',
#   'daily moisturizing lotion',
#   'body lotion pure',
#   'moisture body lotion',
#   'body lotion vitamin',
#   'lotion fragrance free',
#   'regular body lotion',
#   'hand body lotion',
#   'highly recommend lotion',
#   'recommend lotion anyone',
#   'lotion goes smooth',
#   'lotion ive ever',
#   'best lotion ever',
#   'started using lotion',
#   'body face lotion',
#   'need apply lotion',
#   'lotion ever used',
#   'lotion doesnt leave',
#   'lotion worked well',
#   'sensitive face lotion',
#   'lotion every day',
#   'best lotion ive',
#   'continue use lotion',
#   'lotion smells good',
#   'lotion smells great',
#   'lotion works well',
#   'lotion leaves skin',
#   'use body lotion',
#   'body lotion face',
#   'use hand lotion',
#   'lotion ive tried',
#   'lotion makes skin',
#   'lotion ive used',
#   'love lotion smells',
#   'lotion sensitive skin',
#   'feels like lotion',
#   'lotion works great',
#   'lotion would recommend',
#   'lotion smells like',
#   'ive using lotion',
#   'like body lotion',
#   'would recommend lotion',
#   'love smell lotion',
#   'ive used lotion',
#   'lotion ive using',
#   'lotion dry skin',
#   'really like lotion',
#   'dry skin lotion',
#   'lotion make skin'],
#  ['straightener pearl infused',
#   'straightener heats quickly',
#   'ceramic hair straightener',
#   'hair straightener pearl'],
#  ['including waterproof mascara',
#   'remove waterproof mascara',
#   'wear waterproof mascara',
#   'mascara doesnt clump',
#   'eye liner mascara',
#   'even waterproof mascara',
#   'makeup including mascara',
#   'mascara makes lashes',
#   'great lash mascara',
#   'best mascara ever',
#   'mascara ive ever',
#   'use waterproof mascara',
#   'mascara ever used',
#   'absolutely love mascara',
#   'best mascara ive',
#   'mascara ive tried',
#   'dont wear mascara',
#   'using mascara years',
#   'mascara ive used',
#   'ive using mascara',
#   'really like mascara'],
#  ['exfoliating renewal cleanser',
#   'sonic power cleanser',
#   'wave power cleanser',
#   'daily exfoliating cleanser',
#   'power facial cleanser',
#   'straight finish cleanser',
#   'naturally moisturizing cleanser',
#   'daily facial cleanser',
#   'gentle skin cleanser',
#   'good facial cleanser',
#   'clean cream cleanser',
#   'cleanser leaves face',
#   'use facial cleanser',
#   'cleanser works well',
#   'cleanser great job',
#   'cleanser leaves skin',
#   'wash face cleanser',
#   'cleanser sensitive skin',
#   'sensitive skin cleanser',
#   'cleanser works great',
#   'cleanser ive used',
#   'cleanser dry skin',
#   'really like cleanser'],
#  ['detailer shower tool', 'hair styling tool', 'great little tool'],
#  [],
#  ['mercier tinted moisturizer',
#   'replenishing rich moisturizer',
#   'age defying moisturizer',
#   'light moisturizer 42',
#   'green tea moisturizer',
#   'moisturizer spf 30',
#   'tinted moisturizer spf',
#   'moisturizer spf 15',
#   'protecting light moisturizer',
#   'hydrating light moisturizer',
#   'daily moisturizer spf',
#   'cream tinted moisturizer',
#   'moisturizer absorbs quickly',
#   'moisturizer goes smoothly',
#   'moisturizer bb cream',
#   'like tinted moisturizer',
#   'use tinted moisturizer',
#   'light moisturizer spf',
#   'oil free moisturizer',
#   'best moisturizer ever',
#   'night time moisturizer',
#   'moisturizer ive ever',
#   'moisturizer night cream',
#   'moisturizer ever used',
#   'use daily moisturizer',
#   'moisturizer keeps skin',
#   'best moisturizer ive',
#   'started using moisturizer',
#   'nice light moisturizer',
#   'moisturizer works well',
#   'use regular moisturizer',
#   'use facial moisturizer',
#   'moisturizer sensitive skin',
#   'need use moisturizer',
#   'moisturizer ive tried',
#   'moisturizer leaves skin',
#   'moisturizer makes skin',
#   'moisturizer skin feels',
#   'sensitive skin moisturizer',
#   'always use moisturizer',
#   'moisturizer ive using',
#   'moisturizer oily skin',
#   'moisturizer ive used',
#   'use light moisturizer',
#   'use good moisturizer',
#   'moisturizer dry skin',
#   'ive using moisturizer',
#   'still use moisturizer',
#   'really good moisturizer',
#   'really like moisturizer',
#   'use moisturizer face',
#   'oil moisturizer hair',
#   'dont use moisturizer',
#   'dry skin moisturizer',
#   'use face moisturizer',
#   'great moisturizer skin',
#   'use moisturizer skin'],
#  ['irish spring soap',
#   'sea mud soap',
#   'sea salt soap',
#   'african black soap',
#   'foaming hand soap',
#   'tea tree soap',
#   'dove bar soap',
#   'regular bar soap',
#   'liquid hand soap',
#   'olive oil soap',
#   'bar soap body',
#   'easily soap water',
#   'soap lathers well',
#   'soap body wash',
#   'use bar soap',
#   'using bar soap',
#   'wash soap water',
#   'body wash soap',
#   'highly recommend soap',
#   'best soap ever',
#   'like bar soap',
#   'started using soap',
#   'use hand soap',
#   'soap leaves skin',
#   'soap smells good',
#   'love soap smells',
#   'soap wash face',
#   'soap smells great',
#   'soap sensitive skin',
#   'sensitive skin soap',
#   'soap works well',
#   'smells like soap',
#   'soap works great',
#   'soap smells like',
#   'ive using soap',
#   'soap makes skin',
#   'use soap face',
#   'soap dry skin',
#   'really like soap']]

# %%
lh_3
# Out:
# [['highly recommend item',
#   'would recommend item',
#   'item arrived quickly',
#   'item arrived time',
#   'received item free',
#   'item free discount',
#   'matter whether item',
#   'whether item free'],
#  ['stuff highly recommend',
#   'highly recommend stuff',
#   'sensitive skin stuff',
#   'stuff works well',
#   'stuff ive used',
#   'dont know stuff',
#   'stuff dont know',
#   'stuff goes long',
#   'long way stuff',
#   'stuff works great',
#   'started using stuff',
#   'ive using stuff',
#   'stuff ive using',
#   'absolutely love stuff',
#   'really like stuff',
#   'stuff little goes',
#   'love love stuff',
#   'stuff smells great',
#   'stuff smells like',
#   'stuff smells good',
#   'pretty good stuff',
#   'stuff makes hair',
#   'love stuff love',
#   'stuff pretty good',
#   'stuff lasts long',
#   'stuff makes skin',
#   'really love stuff',
#   'love stuff works',
#   'love stuff smells',
#   'really good stuff',
#   'stuff works wonders',
#   'stuff really good',
#   'love stuff makes',
#   'love stuff great',
#   'love stuff really',
#   'best stuff ever',
#   'product love stuff',
#   'love stuff use',
#   'well love stuff',
#   'hair love stuff',
#   'love stuff hair',
#   'love stuff much',
#   'love stuff like',
#   'love stuff ive',
#   'love stuff im',
#   'love stuff using',
#   'love stuff used',
#   'skin love stuff',
#   'love stuff dont',
#   'stuff works better',
#   'stuff smells amazing',
#   'stuff made hair',
#   'stuff works really',
#   'stuff really works',
#   'give stuff try',
#   'hair stuff works',
#   'stuff makes face',
#   'using stuff years',
#   'good stuff like',
#   'great stuff love',
#   'hair loves stuff'],
#  ['vitamin c serum',
#   'serum vitamin c',
#   'serum works well',
#   'serum ive used',
#   'started using serum',
#   'ive using serum',
#   'serum works great',
#   'serum ive using',
#   'hyaluronic acid serum',
#   'serum hyaluronic acid',
#   'really like serum',
#   'vit c serum',
#   'c serum hyaluronic',
#   'c serum face',
#   'c serum really',
#   'serum 2 weeks',
#   'serum absorbs quickly',
#   'serum eye cream',
#   'serum twice day',
#   'serum makes skin',
#   'olay regenerist serum',
#   'serum fragrance free',
#   'anti aging serum',
#   'serum perfective ceuticals',
#   'even glow serum',
#   'age guardian serum',
#   'daily regenerating serum',
#   'guardian serum growth',
#   'smooth infusing serum',
#   'mineral lift serum',
#   'eye lifting serum',
#   'super skinny serum',
#   'skin tightening serum',
#   'lift firm serum',
#   'heat potion serum'],
#  ['highly recommend shampoo',
#   'argan oil shampoo',
#   'would recommend shampoo',
#   'shampoo would recommend',
#   'shampoo works well',
#   'shampoo every day',
#   'every day shampoo',
#   'ive used shampoo',
#   'shampoo ive used',
#   'shampoo dont know',
#   'shampoo ive tried',
#   'shampoo body wash',
#   'body wash shampoo',
#   'shampoo first time',
#   'antidandruff shampoo conditioner',
#   'shampoo conditioner hair',
#   'using shampoo conditioner',
#   'dandruff shampoo conditioner',
#   'regular shampoo conditioner',
#   'matching shampoo conditioner',
#   'shampoo conditioner shampoo',
#   'nourishing shampoo conditioner',
#   'use shampoo conditioner',
#   '1 shampoo conditioner',
#   'shampoo conditioner works',
#   'used shampoo conditioner',
#   'shampoo conditioner leaves',
#   'keratin shampoo conditioner',
#   'started using shampoo',
#   'shampoo conditioner left',
#   'shampoo conditioner smells',
#   'shampoo conditioner combo',
#   '2in1 shampoo conditioner',
#   'shampoo conditioner leave',
#   'care shampoo conditioner',
#   'shampoo conditioner well',
#   'clear shampoo conditioner',
#   'moisturizing shampoo conditioner',
#   'free shampoo conditioner',
#   'shampoo conditioner together',
#   'hair shampoo conditioner',
#   'love shampoo conditioner',
#   'like shampoo conditioner',
#   'shampoo conditioner made',
#   'shampoo conditioner great',
#   'shampoo conditioner body',
#   'separate shampoo conditioner',
#   'product shampoo conditioner',
#   'good shampoo conditioner',
#   'combination shampoo conditioner',
#   'bottles shampoo conditioner',
#   'best shampoo conditioner',
#   'brand shampoo conditioner',
#   'shampoo conditioner product',
#   'shampoo conditioner used',
#   'ive using shampoo',
#   'shampoo conditioner ive',
#   'shampoo conditioner really',
#   'shampoo conditioner also',
#   'shampoo conditioner styling',
#   'bought shampoo conditioner',
#   'shampoo conditioner didnt',
#   'try shampoo conditioner',
#   'shampoo conditioner combination',
#   'scent shampoo conditioner',
#   'tried shampoo conditioner',
#   'purchased shampoo conditioner',
#   'shampoo conditioner would',
#   'shampoo conditioner line',
#   'shampoo conditioner set',
#   'shampoo conditioner nice',
#   'found shampoo conditioner',
#   'shampoo conditioner smell',
#   'shampoo conditioner work',
#   'shampoo conditioner good',
#   'shampoo conditioner first',
#   'shampoo conditioner one',
#   'great shampoo conditioner',
#   'shampoo conditioner 2',
#   'oil shampoo conditioner',
#   'shampoo conditioner like',
#   'shampoo conditioner dont',
#   'shampoo conditioner im',
#   'shampoo conditioner love',
#   'products shampoo conditioner',
#   'shampoo conditioner get',
#   'shampoo conditioner use',
#   'shampoo conditioner using',
#   'shampoo works great',
#   'shampoo ive using',
#   'small amount shampoo',
#   'little bit shampoo',
#   'tea tree shampoo',
#   'feel like shampoo',
#   'really like shampoo',
#   'decided try shampoo',
#   'shampoo leaves hair',
#   'absolutely love shampoo',
#   'continue use shampoo',
#   'shampoo ever used'],
#  ['highly recommend lotion',
#   'lotion sensitive skin',
#   'would recommend lotion',
#   'lotion would recommend',
#   'lotion works well',
#   'lotion every day',
#   'lotion ive used',
#   'ive used lotion',
#   'lotion ive tried',
#   'shea butter lotion',
#   'lotion dry skin',
#   'dry skin lotion',
#   'started using lotion',
#   'ive using lotion',
#   'lotion works great',
#   'lotion ive using',
#   'really like lotion',
#   'continue use lotion',
#   'lotion goes smoothly',
#   'lotion ever used',
#   'lotion ive ever',
#   'lotion leaves skin',
#   'lotion smells great',
#   'lotion absorbs quickly',
#   'lotion doesnt leave',
#   'lotion smells like',
#   'lotion spf 30',
#   'lotion smells good',
#   'lotion makes skin',
#   'lotion worked well',
#   'cocoa butter lotion',
#   'feels like lotion',
#   'lotion spf 15',
#   'best lotion ever',
#   'lotion goes smooth',
#   'infusion body lotion',
#   'spf 15 lotion',
#   'use body lotion',
#   'vaseline body lotion',
#   'moisture body lotion',
#   'body lotion aloe',
#   'regular body lotion',
#   'radiant body lotion',
#   'like body lotion',
#   'body lotion vitamin',
#   'body lotion pure',
#   'hand body lotion',
#   'body lotion face',
#   'recommend lotion anyone',
#   'lotion fragrance free',
#   'self tanning lotion',
#   'love smell lotion',
#   'best lotion ive',
#   'lotion make skin',
#   'sunscreen lotion spf',
#   'gold bond lotion',
#   'daily moisturizing lotion',
#   'hydrate sunscreen lotion',
#   'coolzone sunscreen lotion',
#   'love lotion smells',
#   'cocoa radiant lotion',
#   'like suntan lotion',
#   'body face lotion',
#   'need apply lotion',
#   'use hand lotion',
#   'age repair lotion',
#   'lotion pure oat',
#   'sensitive face lotion',
#   'lotion aloe fresh',
#   'foaming wrap lotion',
#   'gentle soothing lotion'],
#  ['straightener heats quickly',
#   'ceramic hair straightener',
#   'hair straightener pearl',
#   'straightener pearl infused'],
#  ['mascara ive used',
#   'mascara ive tried',
#   'ive using mascara',
#   'really like mascara',
#   'absolutely love mascara',
#   'mascara ive ever',
#   'mascara ever used',
#   'best mascara ever',
#   'remove waterproof mascara',
#   'even waterproof mascara',
#   'wear waterproof mascara',
#   'including waterproof mascara',
#   'use waterproof mascara',
#   'best mascara ive',
#   'eye liner mascara',
#   'mascara makes lashes',
#   'using mascara years',
#   'mascara doesnt clump',
#   'dont wear mascara',
#   'great lash mascara',
#   'makeup including mascara'],
#  ['cleanser sensitive skin',
#   'sensitive skin cleanser',
#   'cleanser works well',
#   'cleanser ive used',
#   'cleanser dry skin',
#   'cleanser works great',
#   'really like cleanser',
#   'cleanser leaves skin',
#   'cleanser great job',
#   'daily facial cleanser',
#   'wash face cleanser',
#   'use facial cleanser',
#   'power facial cleanser',
#   'good facial cleanser',
#   'cleanser leaves face',
#   'gentle skin cleanser',
#   'daily exfoliating cleanser',
#   'exfoliating renewal cleanser',
#   'sonic power cleanser',
#   'wave power cleanser',
#   'straight finish cleanser',
#   'clean cream cleanser',
#   'naturally moisturizing cleanser'],
#  ['hair styling tool', 'detailer shower tool', 'great little tool'],
#  [],
#  ['moisturizer sensitive skin',
#   'sensitive skin moisturizer',
#   'moisturizer works well',
#   'moisturizer ive used',
#   'moisturizer ive tried',
#   'moisturizer dry skin',
#   'dry skin moisturizer',
#   'started using moisturizer',
#   'ive using moisturizer',
#   'moisturizer ive using',
#   'moisturizer bb cream',
#   'really like moisturizer',
#   'moisturizer oily skin',
#   'moisturizer goes smoothly',
#   'moisturizer leaves skin',
#   'moisturizer ever used',
#   'moisturizer ive ever',
#   'moisturizer absorbs quickly',
#   'moisturizer spf 30',
#   'moisturizer makes skin',
#   'moisturizer skin feels',
#   'tinted moisturizer spf',
#   'really good moisturizer',
#   'moisturizer spf 15',
#   'moisturizer night cream',
#   'use tinted moisturizer',
#   'best moisturizer ever',
#   'mercier tinted moisturizer',
#   'cream tinted moisturizer',
#   'like tinted moisturizer',
#   'dont use moisturizer',
#   'use daily moisturizer',
#   'need use moisturizer',
#   'green tea moisturizer',
#   'daily moisturizer spf',
#   'nice light moisturizer',
#   'best moisturizer ive',
#   'use facial moisturizer',
#   'moisturizer keeps skin',
#   'light moisturizer spf',
#   'use regular moisturizer',
#   'age defying moisturizer',
#   'use good moisturizer',
#   'oil free moisturizer',
#   'use face moisturizer',
#   'hydrating light moisturizer',
#   'use light moisturizer',
#   'always use moisturizer',
#   'still use moisturizer',
#   'night time moisturizer',
#   'protecting light moisturizer',
#   'light moisturizer 42',
#   'use moisturizer face',
#   'use moisturizer skin',
#   'replenishing rich moisturizer',
#   'great moisturizer skin',
#   'oil moisturizer hair'],
#  ['highly recommend soap',
#   'soap sensitive skin',
#   'sensitive skin soap',
#   'soap works well',
#   'soap body wash',
#   'body wash soap',
#   'soap dry skin',
#   'started using soap',
#   'ive using soap',
#   'soap works great',
#   'tea tree soap',
#   'really like soap',
#   'soap smells great',
#   'soap leaves skin',
#   'soap smells like',
#   'smells like soap',
#   'soap smells good',
#   'sea salt soap',
#   'dove bar soap',
#   'soap makes skin',
#   'regular bar soap',
#   'use bar soap',
#   'bar soap body',
#   'using bar soap',
#   'like bar soap',
#   'olive oil soap',
#   'sea mud soap',
#   'best soap ever',
#   'soap wash face',
#   'soap lathers well',
#   'irish spring soap',
#   'foaming hand soap',
#   'african black soap',
#   'liquid hand soap',
#   'use hand soap',
#   'wash soap water',
#   'easily soap water',
#   'love soap smells',
#   'use soap face']]

# %%
jaccard_3
# Out:
# [['matter whether item',
#   'item free discount',
#   'whether item free',
#   'item arrived quickly',
#   'received item free',
#   'highly recommend item',
#   'would recommend item',
#   'item arrived time'],
#  ['stuff works great',
#   'absolutely love stuff',
#   'stuff really works',
#   'stuff smells amazing',
#   'stuff works wonders',
#   'stuff smells great',
#   'stuff works well',
#   'stuff highly recommend',
#   'stuff smells good',
#   'best stuff ever',
#   'highly recommend stuff',
#   'long way stuff',
#   'stuff goes long',
#   'love love stuff',
#   'love stuff smells',
#   'really like stuff',
#   'love stuff use',
#   'love stuff makes',
#   'give stuff try',
#   'stuff makes hair',
#   'dont know stuff',
#   'stuff lasts long',
#   'really love stuff',
#   'love stuff great',
#   'stuff ive using',
#   'love stuff ive',
#   'stuff dont know',
#   'love stuff works',
#   'started using stuff',
#   'stuff smells like',
#   'stuff little goes',
#   'stuff works better',
#   'pretty good stuff',
#   'really good stuff',
#   'ive using stuff',
#   'stuff ive used',
#   'love stuff love',
#   'stuff works really',
#   'love stuff really',
#   'stuff makes skin',
#   'stuff makes face',
#   'using stuff years',
#   'love stuff im',
#   'love stuff using',
#   'stuff really good',
#   'stuff pretty good',
#   'sensitive skin stuff',
#   'product love stuff',
#   'stuff made hair',
#   'well love stuff',
#   'love stuff used',
#   'hair love stuff',
#   'great stuff love',
#   'love stuff much',
#   'skin love stuff',
#   'love stuff dont',
#   'hair loves stuff',
#   'hair stuff works',
#   'love stuff like',
#   'good stuff like',
#   'love stuff hair'],
#  ['vitamin c serum',
#   'hyaluronic acid serum',
#   'vit c serum',
#   'mineral lift serum',
#   'guardian serum growth',
#   'age guardian serum',
#   'daily regenerating serum',
#   'serum vitamin c',
#   'serum hyaluronic acid',
#   'even glow serum',
#   'serum perfective ceuticals',
#   'c serum hyaluronic',
#   'lift firm serum',
#   'eye lifting serum',
#   'anti aging serum',
#   'olay regenerist serum',
#   'super skinny serum',
#   'smooth infusing serum',
#   'heat potion serum',
#   'serum absorbs quickly',
#   'serum eye cream',
#   'serum fragrance free',
#   'serum 2 weeks',
#   'c serum face',
#   'serum twice day',
#   'ive using serum',
#   'started using serum',
#   'serum works well',
#   'serum ive used',
#   'c serum really',
#   'serum works great',
#   'really like serum',
#   'skin tightening serum',
#   'serum ive using',
#   'serum makes skin'],
#  ['sea mud shampoo',
#   '2 1 shampoo',
#   'sulfate free shampoo',
#   'shampoo 129 fluid',
#   '1 shampoo conditioner',
#   'nourishing shampoo 129',
#   'using shampoo conditioner',
#   'therapy antidandruff shampoo',
#   'color care shampoo',
#   'shampoo lathers nicely',
#   'infusion shine shampoo',
#   'renewal rejuvenating shampoo',
#   'tea tree shampoo',
#   'shampoo conditioner combo',
#   'moroccan infusion shampoo',
#   'shampoo every day',
#   'youth renewal shampoo',
#   'shampoo matching conditioner',
#   'regular shampoo conditioner',
#   '3 1 shampoo',
#   'rainforest fresh shampoo',
#   'shampoo works well',
#   'weightless moisture shampoo',
#   'shampoo conditioner together',
#   'shampoo lathers well',
#   'shampoo plus conditioner',
#   'cleanse nourish shampoo',
#   'shampoo conditioner body',
#   'shampoo body wash',
#   '1 shampoo plus',
#   'use shampoo conditioner',
#   'control nourishing shampoo',
#   'antidandruff shampoo conditioner',
#   'used shampoo conditioner',
#   'shampoo smells great',
#   'keratin smooth shampoo',
#   'along matching shampoo',
#   'smooth infusing shampoo',
#   'shampoo leaves hair',
#   'oxygen moisture shampoo',
#   'head shoulders shampoo',
#   'boost nourishing shampoo',
#   'argan oil shampoo',
#   'small amount shampoo',
#   'anti dandruff shampoo',
#   'johnsons baby shampoo',
#   'combination shampoo conditioner',
#   'ive using shampoo',
#   '1 antidandruff shampoo',
#   'platinum strength shampoo',
#   'best shampoo ever',
#   'shampoo ive ever',
#   'highly recommend shampoo',
#   'dandruff fortifying shampoo',
#   'end rescue shampoo',
#   'scalp therapy shampoo',
#   'shampoo suave professionals',
#   'clear shampoo conditioner',
#   '2in1 shampoo conditioner',
#   'frizz control shampoo',
#   'shampoo conditioner hair',
#   'bottles shampoo conditioner',
#   'scalp nourishing shampoo',
#   'body wash shampoo',
#   'shampoo works great',
#   'bought shampoo conditioner',
#   'shampoo conditioner one',
#   'shampoo conditioner leave',
#   'shampoo conditioner made',
#   'shampoo conditioner also',
#   'shampoo conditioner left',
#   'really like shampoo',
#   'separate shampoo conditioner',
#   'care nourishing shampoo',
#   'conditioner matching shampoo',
#   'shampoo left hair',
#   'love shampoo conditioner',
#   'shampoo conditioner line',
#   'shampoo cleans well',
#   'nourishing shampoo conditioner',
#   'suave dry shampoo',
#   'shampoo ever used',
#   'purchased shampoo conditioner',
#   'clarifying shampoo week',
#   'shampoo ive tried',
#   'shampoo twice week',
#   'shampoo conditioner styling',
#   'shampoo conditioner smells',
#   'try shampoo conditioner',
#   'shampoo conditioner leaves',
#   'shampoo ive used',
#   'clear scalp shampoo',
#   'shampoo conditioner work',
#   'every day shampoo',
#   'moisturizing shampoo conditioner',
#   'shampoo conditioner works',
#   'shampoo conditioner set',
#   'keratin shampoo conditioner',
#   'shampoo along conditioner',
#   'decided try shampoo'],
#  ['lotion spf 30',
#   'sunscreen lotion spf',
#   'age repair lotion',
#   'hydrate sunscreen lotion',
#   'infusion body lotion',
#   'lotion spf 15',
#   'foaming wrap lotion',
#   'coolzone sunscreen lotion',
#   'lotion absorbs quickly',
#   'self tanning lotion',
#   'lotion goes smoothly',
#   'cocoa butter lotion',
#   'lotion pure oat',
#   'vaseline body lotion',
#   'daily moisturizing lotion',
#   'lotion aloe fresh',
#   'cocoa radiant lotion',
#   'body lotion aloe',
#   'gold bond lotion',
#   'gentle soothing lotion',
#   'shea butter lotion',
#   'radiant body lotion',
#   'spf 15 lotion',
#   'moisture body lotion',
#   'highly recommend lotion',
#   'regular body lotion',
#   'hand body lotion',
#   'lotion ive ever',
#   'body lotion pure',
#   'lotion goes smooth',
#   'lotion fragrance free',
#   'body lotion vitamin',
#   'lotion works well',
#   'body face lotion',
#   'recommend lotion anyone',
#   'best lotion ever',
#   'lotion ive used',
#   'lotion smells great',
#   'lotion smells good',
#   'best lotion ive',
#   'started using lotion',
#   'lotion ever used',
#   'lotion every day',
#   'use body lotion',
#   'need apply lotion',
#   'lotion makes skin',
#   'lotion ive tried',
#   'lotion doesnt leave',
#   'lotion works great',
#   'sensitive face lotion',
#   'really like lotion',
#   'ive using lotion',
#   'lotion leaves skin',
#   'like suntan lotion',
#   'body lotion face',
#   'lotion would recommend',
#   'lotion worked well',
#   'lotion dry skin',
#   'love lotion smells',
#   'dry skin lotion',
#   'feels like lotion',
#   'lotion smells like',
#   'would recommend lotion',
#   'love smell lotion',
#   'ive used lotion',
#   'lotion sensitive skin',
#   'lotion ive using',
#   'use hand lotion',
#   'like body lotion',
#   'continue use lotion',
#   'lotion make skin'],
#  ['straightener pearl infused',
#   'straightener heats quickly',
#   'ceramic hair straightener',
#   'hair straightener pearl'],
#  ['remove waterproof mascara',
#   'including waterproof mascara',
#   'mascara makes lashes',
#   'mascara ive ever',
#   'eye liner mascara',
#   'best mascara ever',
#   'wear waterproof mascara',
#   'even waterproof mascara',
#   'mascara doesnt clump',
#   'mascara ive tried',
#   'makeup including mascara',
#   'best mascara ive',
#   'mascara ever used',
#   'mascara ive used',
#   'really like mascara',
#   'ive using mascara',
#   'great lash mascara',
#   'dont wear mascara',
#   'using mascara years',
#   'absolutely love mascara',
#   'use waterproof mascara'],
#  ['exfoliating renewal cleanser',
#   'wave power cleanser',
#   'sonic power cleanser',
#   'daily exfoliating cleanser',
#   'straight finish cleanser',
#   'power facial cleanser',
#   'naturally moisturizing cleanser',
#   'daily facial cleanser',
#   'cleanser works well',
#   'clean cream cleanser',
#   'cleanser leaves face',
#   'good facial cleanser',
#   'gentle skin cleanser',
#   'cleanser works great',
#   'wash face cleanser',
#   'cleanser sensitive skin',
#   'cleanser ive used',
#   'use facial cleanser',
#   'cleanser leaves skin',
#   'cleanser great job',
#   'really like cleanser',
#   'sensitive skin cleanser',
#   'cleanser dry skin'],
#  ['detailer shower tool', 'great little tool', 'hair styling tool'],
#  [],
#  ['moisturizer spf 30',
#   'moisturizer spf 15',
#   'hydrating light moisturizer',
#   'replenishing rich moisturizer',
#   'green tea moisturizer',
#   'age defying moisturizer',
#   'mercier tinted moisturizer',
#   'daily moisturizer spf',
#   'tinted moisturizer spf',
#   'night time moisturizer',
#   'protecting light moisturizer',
#   'moisturizer absorbs quickly',
#   'moisturizer goes smoothly',
#   'moisturizer bb cream',
#   'moisturizer ive ever',
#   'best moisturizer ever',
#   'oil free moisturizer',
#   'cream tinted moisturizer',
#   'light moisturizer 42',
#   'light moisturizer spf',
#   'moisturizer works well',
#   'moisturizer night cream',
#   'best moisturizer ive',
#   'moisturizer ever used',
#   'use good moisturizer',
#   'need use moisturizer',
#   'like tinted moisturizer',
#   'nice light moisturizer',
#   'moisturizer ive using',
#   'use tinted moisturizer',
#   'moisturizer dry skin',
#   'moisturizer makes skin',
#   'use daily moisturizer',
#   'moisturizer ive used',
#   'moisturizer ive tried',
#   'started using moisturizer',
#   'moisturizer sensitive skin',
#   'really like moisturizer',
#   'moisturizer skin feels',
#   'really good moisturizer',
#   'ive using moisturizer',
#   'always use moisturizer',
#   'use regular moisturizer',
#   'use light moisturizer',
#   'moisturizer leaves skin',
#   'sensitive skin moisturizer',
#   'use moisturizer face',
#   'moisturizer keeps skin',
#   'use facial moisturizer',
#   'moisturizer oily skin',
#   'dont use moisturizer',
#   'still use moisturizer',
#   'use face moisturizer',
#   'dry skin moisturizer',
#   'great moisturizer skin',
#   'oil moisturizer hair',
#   'use moisturizer skin'],
#  ['african black soap',
#   'sea mud soap',
#   'sea salt soap',
#   'dove bar soap',
#   'foaming hand soap',
#   'irish spring soap',
#   'liquid hand soap',
#   'tea tree soap',
#   'regular bar soap',
#   'soap body wash',
#   'easily soap water',
#   'olive oil soap',
#   'body wash soap',
#   'wash soap water',
#   'bar soap body',
#   'highly recommend soap',
#   'best soap ever',
#   'use bar soap',
#   'soap lathers well',
#   'started using soap',
#   'using bar soap',
#   'soap smells good',
#   'soap smells great',
#   'soap works well',
#   'love soap smells',
#   'soap leaves skin',
#   'soap wash face',
#   'use hand soap',
#   'soap sensitive skin',
#   'soap works great',
#   'ive using soap',
#   'sensitive skin soap',
#   'like bar soap',
#   'use soap face',
#   'really like soap',
#   'smells like soap',
#   'soap makes skin',
#   'soap smells like',
#   'soap dry skin']]

# %% [markdown]
# финальный результат для биграмм и триграмм:

# %%
final_bigrams = []
for item in range(0, len(pmi)):
    inter = set(pmi[item]).intersection(lh[item], jaccard[item])
    final_bigrams.append(inter)

# %%
for num, bigrams in enumerate(final_bigrams):
    print('биграммы для слова', words[num], ':', list(bigrams)[:5])
# Out:
# биграммы для слова item : ['item im', 'particular item', 'nice item', 'item would', 'item purchased']
# биграммы для слова stuff : ['white stuff', 'stuff leaves', 'stuff ever', 'stuff keeps', 'best stuff']
# биграммы для слова serum : ['guardian serum', 'serum smells', 'frizz serum', 'retinol serum', 'serum add']
# биграммы для слова shampoo : ['mud shampoo', 'volumizing shampoo', 'matching shampoo', 'conditioning shampoo', 'dry shampoo']
# биграммы для слова lotion : ['apply lotion', 'putting lotion', 'vaseline lotion', 'moisture lotion', 'drying lotion']
# биграммы для слова straightener : ['love straightener', 'dryer straightener', 'straightener worked', 'chi straightener', 'iron straightener']
# биграммы для слова mascara : ['mascara black', 'wearing mascara', 'mascara ever', 'mascara eyelashes', 'mascara wand']
# биграммы для слова cleanser : ['cleanser leaves', 'renewal cleanser', 'another cleanser', 'cleanser scrub', 'cleanser cleanser']
# биграммы для слова tool : ['tool would', 'using tool', 'good tool', 'tool also', 'tool one']
# биграммы для слова device : ['use device', 'using device', 'little device', 'device works']
# биграммы для слова moisturizer : ['light moisturizer', 'excellent moisturizer', 'olay moisturizer', 'moisturizer foundation', 'oilfree moisturizer']
# биграммы для слова soap : ['soap water', 'soap soap', 'tree soap', 'bars soap', 'soap nuts']

# %%
final_trigrams = []
for item in range(0, len(pmi_3)):
    inter = set(pmi_3[item]).intersection(lh_3[item], jaccard_3[item])
    final_trigrams.append(inter)

# %%
for num, trigrams in enumerate(final_trigrams):
    print('триграммы для слова', words[num], ':', list(trigrams)[:5])
# Out:
# триграммы для слова item : ['matter whether item', 'highly recommend item', 'item arrived quickly', 'received item free', 'item free discount']
# триграммы для слова stuff : ['stuff works well', 'ive using stuff', 'stuff made hair', 'great stuff love', 'good stuff like']
# триграммы для слова serum : ['serum works well', 'ive using serum', 'serum twice day', 'serum 2 weeks', 'guardian serum growth']
# триграммы для слова shampoo : ['1 shampoo conditioner', 'body wash shampoo', 'nourishing shampoo conditioner', 'shampoo conditioner leave', 'highly recommend shampoo']
# триграммы для слова lotion : ['would recommend lotion', 'lotion every day', 'highly recommend lotion', 'lotion pure oat', 'foaming wrap lotion']
# триграммы для слова straightener : ['ceramic hair straightener', 'straightener heats quickly', 'straightener pearl infused', 'hair straightener pearl']
# триграммы для слова mascara : ['mascara ever used', 'really like mascara', 'mascara ive ever', 'eye liner mascara', 'ive using mascara']
# триграммы для слова cleanser : ['daily exfoliating cleanser', 'cleanser works well', 'power facial cleanser', 'naturally moisturizing cleanser', 'use facial cleanser']
# триграммы для слова tool : ['hair styling tool', 'great little tool', 'detailer shower tool']
# триграммы для слова device : []
# триграммы для слова moisturizer : ['moisturizer makes skin', 'moisturizer spf 15', 'use facial moisturizer', 'still use moisturizer', 'great moisturizer skin']
# триграммы для слова soap : ['african black soap', 'olive oil soap', 'sea mud soap', 'soap smells great', 'smells like soap']

# %% [markdown]
# Можно заметить, что слова stuff, product, которые являются референтами к продуктам, используются в основном для оценки товара (highly recommend item, great stuff love), в то время как слова, которые более конктретно отражают продукт типа shampoo, oil используются с их описательными характеристиками (olive oil, body wash shampoo).
